# %%
import os
import sys
import json
import logging
import boto3
import requests
from datetime import datetime
from dotenv import load_dotenv
from utils.models import StateVector

load_dotenv()

# AWS clients
secrets_client = boto3.client("secretsmanager")
kinesis_client = boto3.client("kinesis")

# OpenSky OAuth2 + API endpoints
OPENSKY_TOKEN_URL = (
    "https://auth.opensky-network.org/auth/realms/opensky-network/protocol/openid-connect/token"
)
OPENSKY_STATES_URL = "https://opensky-network.org/api/states/all"

# %%
# logging 

logger = logging.getLogger()
logger.setLevel(logging.INFO)

if not logger.handlers:
    handler = logging.StreamHandler(sys.stdout)
    formatter = logging.Formatter(
        "%(asctime)s - %(levelname)s - %(name)s - %(message)s"
    )
    handler.setFormatter(formatter)
    logger.addHandler(handler)

# %%
# opensky functions 

def _get_opensky_credentials_from_secret():
    """
    Lê client_id e client_secret do AWS Secrets Manager.

    Espera que o secret (apontado por OPENSKY_SECRET_ARN) tenha o formato:
    {
      "client_id": "xxxx",
      "client_secret": "yyyy"
    }
    """
    try:
        client_id = os.environ.get("OPENSKY_CLIENT_ID")
        client_secret = os.environ.get("OPENSKY_CLIENT_SECRET")
        if not client_id or not client_secret:
            logger.error("Credentials is missing in secret")
            return None, None
        return client_id, client_secret
    except Exception as e:
        logger.error(f"Error retrieving OpenSky credentials from Secrets Manager: {e}")
        return None, None

def get_opensky_access_token():
    """
    Autentica na OpenSky via OAuth2 Client Credentials e retorna o access_token (Bearer).
    """
    client_id, client_secret = _get_opensky_credentials_from_secret()
    if not client_id or not client_secret:
        return None

    data = {
        "grant_type": "client_credentials",
        "client_id": client_id,
        "client_secret": client_secret,
    }

    try:
        resp = requests.post(OPENSKY_TOKEN_URL, data=data, timeout=10)
        resp.raise_for_status()
        access_token = resp.json().get("access_token")
        if not access_token:
            logger.error("No access_token in OpenSky auth response")
            return None
        logger.info("Successfully obtained OpenSky access token")
        return access_token
    except requests.RequestException as e:
        logger.error(f"Error obtaining OpenSky access token: {e}")
        return None

def convert_states_response_to_json(states: list[StateVector]) -> dict:
    json_data = {
        "timestamp": datetime.now().isoformat(),
        "total_states": 0,
        "states": [],
    }
    for state in states:
        json_data["states"].append(state.to_dict())

    json_data["total_states"] = len(json_data["states"])
    return json_data

def send_states_to_kinesis(json_resultado: dict, batch_size: int = 500) -> bool:
    """
    Envia todos os estados para o Kinesis usando PutRecords em batch.

    Retorna True se todos forem enviados com sucesso, False caso haja falhas.
    """
    stream_name = os.environ.get("KINESIS_STREAM")
    if not stream_name:
        logger.error("KINESIS_STREAM environment variable not set")
        return False

    states = json_resultado["states"]
    if not states:
        logger.info("No states to send to Kinesis")
        return True

    logger.info(f"Sending {len(states)} states to Kinesis stream '{stream_name}' in batches of {batch_size}...")

    all_ok = True

    # Monta todos os records
    records = [
        {
            "Data": json.dumps(state),
            "PartitionKey": state.get("icao24") or "unknown",
        }
        for state in states
    ]

    # Envia em lotes de até 500 registros (limite do Kinesis PutRecords)
    for i in range(0, len(records), batch_size):
        batch = records[i : i + batch_size]
        try:
            response = kinesis_client.put_records(
                StreamName=stream_name,
                Records=batch,
            )
            failed = response.get("FailedRecordCount", 0)
            if failed > 0:
                all_ok = False
                logger.error(
                    f"Batch {i//batch_size} - {failed}/{len(batch)} records failed"
                )
            else:
                logger.info(
                    f"Batch {i//batch_size} - sent {len(batch)} records successfully"
                )
        except Exception as e:
            all_ok = False
            logger.error(f"Error sending batch {i//batch_size} to Kinesis: {e}")

    logger.info(f"Finished sending {len(states)} states to Kinesis (batched)")
    return all_ok


def get_opensky_states(access_token):
    """
    Chama o endpoint /api/states/all usando Bearer token e
    retorna uma lista de StateVector.
    """
    headers = {"Authorization": f"Bearer {access_token}"}

    try:
        resp = requests.get(OPENSKY_STATES_URL, headers=headers, timeout=15)
        resp.raise_for_status()
        body = resp.json()
    except requests.RequestException as e:
        logger.error(f"Error calling OpenSky states API: {e}")
        return []

    raw_states = body.get("states", []) or []
    states: list[StateVector] = []

    for row in raw_states:
        try:
            state = StateVector.from_api_response(row)
            states.append(state)
        except Exception as e:
            logger.warning(f"Failed to parse state vector: {e}")

    logger.info(f"Retrieved {len(states)} state vectors from OpenSky API")
    return states

# %%
from asyncio import sleep
duration = 60
dt_start = datetime.now().isoformat()

while True:
    access_token = get_opensky_access_token()
    states = get_opensky_states(access_token)
    json_resultado = convert_states_response_to_json(states)
    ok = send_states_to_kinesis(json_resultado)
    # await sleep(45)
    elapsed = (datetime.now() - datetime.fromisoformat(dt_start)).total_seconds()
    if elapsed  > duration:
        break
# Out:
# 2026-03-16 17:40:12,225 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-16 17:40:14,357 - INFO - root - Retrieved 8925 state vectors from OpenSky API
# 2026-03-16 17:40:14,420 - INFO - root - Sending 8925 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-16 17:40:16,319 - INFO - root - Batch 0 - sent 500 records successfully
# 2026-03-16 17:40:16,790 - INFO - root - Batch 1 - sent 500 records successfully
# 2026-03-16 17:40:17,292 - INFO - root - Batch 2 - sent 500 records successfully
# 2026-03-16 17:40:17,777 - INFO - root - Batch 3 - sent 500 records successfully
# 2026-03-16 17:40:18,062 - INFO - root - Batch 4 - sent 500 records successfully
# 2026-03-16 17:40:18,362 - INFO - root - Batch 5 - sent 500 records successfully
# 2026-03-16 17:40:18,705 - INFO - root - Batch 6 - sent 500 records successfully
# 2026-03-16 17:40:19,034 - INFO - root - Batch 7 - sent 500 records successfully
# 2026-03-16 17:40:19,376 - INFO - root - Batch 8 - sent 500 records successfully
# 2026-03-16 17:40:19,696 - INFO - root - Batch 9 - sent 500 records successfully
# 2026-03-16 17:40:20,023 - INFO - root - Batch 10 - sent 500 records successfully
# 2026-03-16 17:40:20,353 - INFO - root - Batch 11 - sent 500 records successfully
# 2026-03-16 17:40:20,677 - INFO - root - Batch 12 - sent 500 records successfully
# 2026-03-16 17:40:21,026 - INFO - root - Batch 13 - sent 500 records successfully
# 2026-03-16 17:40:21,342 - INFO - root - Batch 14 - sent 500 records successfully
# 2026-03-16 17:40:21,660 - INFO - root - Batch 15 - sent 500 records successfully
# 2026-03-16 17:40:21,981 - INFO - root - Batch 16 - sent 500 records successfully
# 2026-03-16 17:40:22,294 - INFO - root - Batch 17 - sent 425 records successfully
# 2026-03-16 17:40:22,297 - INFO - root - Finished sending 8925 states to Kinesis (batched)
# 2026-03-16 17:40:23,408 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-16 17:40:25,906 - INFO - root - Retrieved 8931 state vectors from OpenSky API
# 2026-03-16 17:40:25,997 - INFO - root - Sending 8931 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-16 17:40:26,612 - INFO - root - Batch 0 - sent 500 records successfully
# 2026-03-16 17:40:26,933 - INFO - root - Batch 1 - sent 500 records successfully
# 2026-03-16 17:40:27,282 - INFO - root - Batch 2 - sent 500 records successfully
# 2026-03-16 17:40:27,588 - INFO - root - Batch 3 - sent 500 records successfully
# 2026-03-16 17:40:27,906 - INFO - root - Batch 4 - sent 500 records successfully
# 2026-03-16 17:40:28,262 - INFO - root - Batch 5 - sent 500 records successfully
# 2026-03-16 17:40:28,591 - INFO - root - Batch 6 - sent 500 records successfully
# 2026-03-16 17:40:28,947 - INFO - root - Batch 7 - sent 500 records successfully
# 2026-03-16 17:40:29,288 - INFO - root - Batch 8 - sent 500 records successfully
# 2026-03-16 17:40:29,633 - INFO - root - Batch 9 - sent 500 records successfully
# 2026-03-16 17:40:29,982 - INFO - root - Batch 10 - sent 500 records successfully
# 2026-03-16 17:40:30,314 - INFO - root - Batch 11 - sent 500 records successfully
# 2026-03-16 17:40:30,645 - INFO - root - Batch 12 - sent 500 records successfully
# 2026-03-16 17:40:30,984 - INFO - root - Batch 13 - sent 500 records successfully
# 2026-03-16 17:40:31,313 - INFO - root - Batch 14 - sent 500 records successfully
# 2026-03-16 17:40:31,613 - INFO - root - Batch 15 - sent 500 records successfully
# 2026-03-16 17:40:31,913 - INFO - root - Batch 16 - sent 500 records successfully
# 2026-03-16 17:40:32,196 - INFO - root - Batch 17 - sent 431 records successfully
# 2026-03-16 17:40:32,198 - INFO - root - Finished sending 8931 states to Kinesis (batched)
# 2026-03-16 17:40:33,395 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-16 17:40:35,694 - INFO - root - Retrieved 8940 state vectors from OpenSky API
# 2026-03-16 17:40:35,783 - INFO - root - Sending 8940 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-16 17:40:36,494 - INFO - root - Batch 0 - sent 500 records successfully
# 2026-03-16 17:40:36,799 - INFO - root - Batch 1 - sent 500 records successfully
# 2026-03-16 17:40:37,111 - INFO - root - Batch 2 - sent 500 records successfully
# 2026-03-16 17:40:37,426 - INFO - root - Batch 3 - sent 500 records successfully
# 2026-03-16 17:40:37,735 - INFO - root - Batch 4 - sent 500 records successfully
# 2026-03-16 17:40:38,042 - INFO - root - Batch 5 - sent 500 records successfully
# 2026-03-16 17:40:38,349 - INFO - root - Batch 6 - sent 500 records successfully
# 2026-03-16 17:40:38,653 - INFO - root - Batch 7 - sent 500 records successfully
# 2026-03-16 17:40:38,953 - INFO - root - Batch 8 - sent 500 records successfully
# 2026-03-16 17:40:39,250 - INFO - root - Batch 9 - sent 500 records successfully
# 2026-03-16 17:40:39,571 - INFO - root - Batch 10 - sent 500 records successfully
# 2026-03-16 17:40:40,080 - INFO - root - Batch 11 - sent 500 records successfully
# 2026-03-16 17:40:40,421 - INFO - root - Batch 12 - sent 500 records successfully
# 2026-03-16 17:40:40,886 - INFO - root - Batch 13 - sent 500 records successfully
# 2026-03-16 17:40:41,220 - INFO - root - Batch 14 - sent 500 records successfully
# 2026-03-16 17:40:41,532 - INFO - root - Batch 15 - sent 500 records successfully
# 2026-03-16 17:40:41,851 - INFO - root - Batch 16 - sent 500 records successfully
# 2026-03-16 17:40:42,154 - INFO - root - Batch 17 - sent 440 records successfully
# 2026-03-16 17:40:42,157 - INFO - root - Finished sending 8940 states to Kinesis (batched)
# 2026-03-16 17:40:43,157 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-16 17:40:45,536 - INFO - root - Retrieved 8927 state vectors from OpenSky API
# 2026-03-16 17:40:45,615 - INFO - root - Sending 8927 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-16 17:40:46,253 - INFO - root - Batch 0 - sent 500 records successfully
# 2026-03-16 17:40:46,548 - INFO - root - Batch 1 - sent 500 records successfully
# 2026-03-16 17:40:46,840 - INFO - root - Batch 2 - sent 500 records successfully
# 2026-03-16 17:40:47,176 - INFO - root - Batch 3 - sent 500 records successfully
# 2026-03-16 17:40:47,661 - INFO - root - Batch 4 - sent 500 records successfully
# 2026-03-16 17:40:48,001 - INFO - root - Batch 5 - sent 500 records successfully
# 2026-03-16 17:40:48,320 - INFO - root - Batch 6 - sent 500 records successfully
# 2026-03-16 17:40:48,648 - INFO - root - Batch 7 - sent 500 records successfully
# 2026-03-16 17:40:48,980 - INFO - root - Batch 8 - sent 500 records successfully
# 2026-03-16 17:40:49,280 - INFO - root - Batch 9 - sent 500 records successfully
# 2026-03-16 17:40:49,576 - INFO - root - Batch 10 - sent 500 records successfully
# 2026-03-16 17:40:49,876 - INFO - root - Batch 11 - sent 500 records successfully
# 2026-03-16 17:40:50,182 - INFO - root - Batch 12 - sent 500 records successfully
# 2026-03-16 17:40:50,475 - INFO - root - Batch 13 - sent 500 records successfully
# 2026-03-16 17:40:50,767 - INFO - root - Batch 14 - sent 500 records successfully
# 2026-03-16 17:40:51,089 - INFO - root - Batch 15 - sent 500 records successfully
# 2026-03-16 17:40:51,398 - INFO - root - Batch 16 - sent 500 records successfully
# 2026-03-16 17:40:51,707 - INFO - root - Batch 17 - sent 427 records successfully
# 2026-03-16 17:40:51,709 - INFO - root - Finished sending 8927 states to Kinesis (batched)
# 2026-03-16 17:40:52,698 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-16 17:40:55,082 - INFO - root - Retrieved 8942 state vectors from OpenSky API
# 2026-03-16 17:40:55,154 - INFO - root - Sending 8942 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-16 17:40:55,756 - INFO - root - Batch 0 - sent 500 records successfully
# 2026-03-16 17:40:56,040 - INFO - root - Batch 1 - sent 500 records successfully
# 2026-03-16 17:40:56,335 - INFO - root - Batch 2 - sent 500 records successfully
# 2026-03-16 17:40:56,619 - INFO - root - Batch 3 - sent 500 records successfully
# 2026-03-16 17:40:56,918 - INFO - root - Batch 4 - sent 500 records successfully
# 2026-03-16 17:40:57,215 - INFO - root - Batch 5 - sent 500 records successfully
# 2026-03-16 17:40:57,503 - INFO - root - Batch 6 - sent 500 records successfully
# 2026-03-16 17:40:57,798 - INFO - root - Batch 7 - sent 500 records successfully
# 2026-03-16 17:40:58,092 - INFO - root - Batch 8 - sent 500 records successfully
# 2026-03-16 17:40:58,382 - INFO - root - Batch 9 - sent 500 records successfully
# 2026-03-16 17:40:58,677 - INFO - root - Batch 10 - sent 500 records successfully
# 2026-03-16 17:40:59,019 - INFO - root - Batch 11 - sent 500 records successfully
# 2026-03-16 17:40:59,325 - INFO - root - Batch 12 - sent 500 records successfully
# 2026-03-16 17:40:59,609 - INFO - root - Batch 13 - sent 500 records successfully
# 2026-03-16 17:41:00,092 - INFO - root - Batch 14 - sent 500 records successfully
# 2026-03-16 17:41:00,411 - INFO - root - Batch 15 - sent 500 records successfully
# 2026-03-16 17:41:00,720 - INFO - root - Batch 16 - sent 500 records successfully
# 2026-03-16 17:41:01,038 - INFO - root - Batch 17 - sent 442 records successfully
# 2026-03-16 17:41:01,042 - INFO - root - Finished sending 8942 states to Kinesis (batched)
# 2026-03-16 17:41:02,103 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-16 17:41:04,431 - INFO - root - Retrieved 8942 state vectors from OpenSky API
# 2026-03-16 17:41:04,532 - INFO - root - Sending 8942 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-16 17:41:05,190 - INFO - root - Batch 0 - sent 500 records successfully
# 2026-03-16 17:41:05,663 - INFO - root - Batch 1 - sent 500 records successfully
# 2026-03-16 17:41:06,192 - INFO - root - Batch 2 - sent 500 records successfully
# 2026-03-16 17:41:06,526 - INFO - root - Batch 3 - sent 500 records successfully
# 2026-03-16 17:41:06,858 - INFO - root - Batch 4 - sent 500 records successfully
# 2026-03-16 17:41:07,204 - INFO - root - Batch 5 - sent 500 records successfully
# 2026-03-16 17:41:07,531 - INFO - root - Batch 6 - sent 500 records successfully
# 2026-03-16 17:41:07,849 - INFO - root - Batch 7 - sent 500 records successfully
# 2026-03-16 17:41:08,197 - INFO - root - Batch 8 - sent 500 records successfully
# 2026-03-16 17:41:08,525 - INFO - root - Batch 9 - sent 500 records successfully
# 2026-03-16 17:41:09,026 - INFO - root - Batch 10 - sent 500 records successfully
# 2026-03-16 17:41:09,644 - INFO - root - Batch 11 - sent 500 records successfully
# 2026-03-16 17:41:09,992 - INFO - root - Batch 12 - sent 500 records successfully
# 2026-03-16 17:41:10,453 - INFO - root - Batch 13 - sent 500 records successfully
# 2026-03-16 17:41:10,812 - INFO - root - Batch 14 - sent 500 records successfully
# 2026-03-16 17:41:11,169 - INFO - root - Batch 15 - sent 500 records successfully
# 2026-03-16 17:41:11,644 - INFO - root - Batch 16 - sent 500 records successfully
# 2026-03-16 17:41:11,989 - INFO - root - Batch 17 - sent 442 records successfully
# 2026-03-16 17:41:11,992 - INFO - root - Finished sending 8942 states to Kinesis (batched)

# %%
from asyncio import sleep
duration = 310
# await sleep(60)
dt_start = datetime.now().isoformat()

while True:
    access_token = get_opensky_access_token()
    states = get_opensky_states(access_token)
    json_resultado = convert_states_response_to_json(states)
    ok = send_states_to_kinesis(json_resultado)
    # await sleep(60)
    elapsed = (datetime.now() - datetime.fromisoformat(dt_start)).total_seconds()
    if elapsed  > duration:
        break
# Out:
# 2026-03-16 17:41:13,162 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-16 17:41:15,507 - INFO - root - Retrieved 8925 state vectors from OpenSky API
# 2026-03-16 17:41:15,585 - INFO - root - Sending 8925 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-16 17:41:16,246 - INFO - root - Batch 0 - sent 500 records successfully
# 2026-03-16 17:41:16,679 - INFO - root - Batch 1 - sent 500 records successfully
# 2026-03-16 17:41:17,147 - INFO - root - Batch 2 - sent 500 records successfully
# 2026-03-16 17:41:17,945 - INFO - root - Batch 3 - sent 500 records successfully
# 2026-03-16 17:41:18,422 - INFO - root - Batch 4 - sent 500 records successfully
# 2026-03-16 17:41:18,839 - INFO - root - Batch 5 - sent 500 records successfully
# 2026-03-16 17:41:19,254 - INFO - root - Batch 6 - sent 500 records successfully
# 2026-03-16 17:41:19,681 - INFO - root - Batch 7 - sent 500 records successfully
# 2026-03-16 17:41:20,118 - INFO - root - Batch 8 - sent 500 records successfully
# 2026-03-16 17:41:20,583 - INFO - root - Batch 9 - sent 500 records successfully
# 2026-03-16 17:41:21,034 - INFO - root - Batch 10 - sent 500 records successfully
# 2026-03-16 17:41:21,497 - INFO - root - Batch 11 - sent 500 records successfully
# 2026-03-16 17:41:21,944 - INFO - root - Batch 12 - sent 500 records successfully
# 2026-03-16 17:41:22,383 - INFO - root - Batch 13 - sent 500 records successfully
# 2026-03-16 17:41:22,841 - INFO - root - Batch 14 - sent 500 records successfully
# 2026-03-16 17:41:23,316 - INFO - root - Batch 15 - sent 500 records successfully
# 2026-03-16 17:41:23,916 - INFO - root - Batch 16 - sent 500 records successfully
# 2026-03-16 17:41:24,336 - INFO - root - Batch 17 - sent 425 records successfully
# 2026-03-16 17:41:24,339 - INFO - root - Finished sending 8925 states to Kinesis (batched)
# 2026-03-16 17:41:25,396 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-16 17:41:27,751 - INFO - root - Retrieved 8924 state vectors from OpenSky API
# 2026-03-16 17:41:27,833 - INFO - root - Sending 8924 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-16 17:41:28,449 - INFO - root - Batch 0 - sent 500 records successfully
# 2026-03-16 17:41:28,903 - INFO - root - Batch 1 - sent 500 records successfully
# 2026-03-16 17:41:29,516 - INFO - root - Batch 2 - sent 500 records successfully
# 2026-03-16 17:41:29,982 - INFO - root - Batch 3 - sent 500 records successfully
# 2026-03-16 17:41:30,436 - INFO - root - Batch 4 - sent 500 records successfully
# 2026-03-16 17:41:30,899 - INFO - root - Batch 5 - sent 500 records successfully
# 2026-03-16 17:41:31,349 - INFO - root - Batch 6 - sent 500 records successfully
# 2026-03-16 17:41:31,794 - INFO - root - Batch 7 - sent 500 records successfully
# 2026-03-16 17:41:32,260 - INFO - root - Batch 8 - sent 500 records successfully
# 2026-03-16 17:41:32,708 - INFO - root - Batch 9 - sent 500 records successfully
# 2026-03-16 17:41:33,177 - INFO - root - Batch 10 - sent 500 records successfully
# 2026-03-16 17:41:33,668 - INFO - root - Batch 11 - sent 500 records successfully
# 2026-03-16 17:41:34,125 - INFO - root - Batch 12 - sent 500 records successfully
# 2026-03-16 17:41:34,565 - INFO - root - Batch 13 - sent 500 records successfully
# 2026-03-16 17:41:35,055 - INFO - root - Batch 14 - sent 500 records successfully
# 2026-03-16 17:41:35,531 - INFO - root - Batch 15 - sent 500 records successfully
# 2026-03-16 17:41:35,989 - INFO - root - Batch 16 - sent 500 records successfully
# 2026-03-16 17:41:36,437 - INFO - root - Batch 17 - sent 424 records successfully
# 2026-03-16 17:41:36,440 - INFO - root - Finished sending 8924 states to Kinesis (batched)
# 2026-03-16 17:41:37,450 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-16 17:41:40,439 - INFO - root - Retrieved 8916 state vectors from OpenSky API
# 2026-03-16 17:41:40,511 - INFO - root - Sending 8916 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-16 17:41:41,670 - INFO - root - Batch 0 - sent 500 records successfully
# 2026-03-16 17:41:42,108 - INFO - root - Batch 1 - sent 500 records successfully
# 2026-03-16 17:41:42,556 - INFO - root - Batch 2 - sent 500 records successfully
# 2026-03-16 17:41:43,171 - INFO - root - Batch 3 - sent 500 records successfully
# 2026-03-16 17:41:43,770 - INFO - root - Batch 4 - sent 500 records successfully
# 2026-03-16 17:41:44,392 - INFO - root - Batch 5 - sent 500 records successfully
# 2026-03-16 17:41:44,846 - INFO - root - Batch 6 - sent 500 records successfully
# 2026-03-16 17:41:45,311 - INFO - root - Batch 7 - sent 500 records successfully
# 2026-03-16 17:41:45,755 - INFO - root - Batch 8 - sent 500 records successfully
# 2026-03-16 17:41:46,175 - INFO - root - Batch 9 - sent 500 records successfully
# 2026-03-16 17:41:46,724 - INFO - root - Batch 10 - sent 500 records successfully
# 2026-03-16 17:41:47,155 - INFO - root - Batch 11 - sent 500 records successfully
# 2026-03-16 17:41:47,754 - INFO - root - Batch 12 - sent 500 records successfully
# 2026-03-16 17:41:48,310 - INFO - root - Batch 13 - sent 500 records successfully
# 2026-03-16 17:41:48,891 - INFO - root - Batch 14 - sent 500 records successfully
# 2026-03-16 17:41:49,457 - INFO - root - Batch 15 - sent 500 records successfully
# 2026-03-16 17:41:50,037 - INFO - root - Batch 16 - sent 500 records successfully
# 2026-03-16 17:41:50,474 - INFO - root - Batch 17 - sent 416 records successfully
# 2026-03-16 17:41:50,477 - INFO - root - Finished sending 8916 states to Kinesis (batched)
# 2026-03-16 17:41:51,457 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-16 17:41:53,910 - INFO - root - Retrieved 8920 state vectors from OpenSky API
# 2026-03-16 17:41:53,997 - INFO - root - Sending 8920 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-16 17:41:54,611 - INFO - root - Batch 0 - sent 500 records successfully
# 2026-03-16 17:41:55,045 - INFO - root - Batch 1 - sent 500 records successfully
# 2026-03-16 17:41:55,506 - INFO - root - Batch 2 - sent 500 records successfully
# 2026-03-16 17:41:55,943 - INFO - root - Batch 3 - sent 500 records successfully
# 2026-03-16 17:41:56,363 - INFO - root - Batch 4 - sent 500 records successfully
# 2026-03-16 17:41:56,775 - INFO - root - Batch 5 - sent 500 records successfully
# 2026-03-16 17:41:57,415 - INFO - root - Batch 6 - sent 500 records successfully
# 2026-03-16 17:41:58,007 - INFO - root - Batch 7 - sent 500 records successfully
# 2026-03-16 17:41:58,545 - INFO - root - Batch 8 - sent 500 records successfully
# 2026-03-16 17:41:59,107 - INFO - root - Batch 9 - sent 500 records successfully
# 2026-03-16 17:41:59,694 - INFO - root - Batch 10 - sent 500 records successfully
# 2026-03-16 17:42:00,234 - INFO - root - Batch 11 - sent 500 records successfully
# 2026-03-16 17:42:00,779 - INFO - root - Batch 12 - sent 500 records successfully
# 2026-03-16 17:42:01,326 - INFO - root - Batch 13 - sent 500 records successfully
# 2026-03-16 17:42:01,962 - INFO - root - Batch 14 - sent 500 records successfully
# 2026-03-16 17:42:02,364 - INFO - root - Batch 15 - sent 500 records successfully
# 2026-03-16 17:42:02,760 - INFO - root - Batch 16 - sent 500 records successfully
# 2026-03-16 17:42:03,146 - INFO - root - Batch 17 - sent 420 records successfully
# 2026-03-16 17:42:03,149 - INFO - root - Finished sending 8920 states to Kinesis (batched)
# 2026-03-16 17:42:04,167 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-16 17:42:06,635 - INFO - root - Retrieved 8925 state vectors from OpenSky API
# 2026-03-16 17:42:06,732 - INFO - root - Sending 8925 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-16 17:42:07,378 - INFO - root - Batch 0 - sent 500 records successfully
# 2026-03-16 17:42:07,800 - INFO - root - Batch 1 - sent 500 records successfully
# 2026-03-16 17:42:08,244 - INFO - root - Batch 2 - sent 500 records successfully
# 2026-03-16 17:42:08,677 - INFO - root - Batch 3 - sent 500 records successfully
# 2026-03-16 17:42:09,104 - INFO - root - Batch 4 - sent 500 records successfully
# 2026-03-16 17:42:09,533 - INFO - root - Batch 5 - sent 500 records successfully
# 2026-03-16 17:42:09,991 - INFO - root - Batch 6 - sent 500 records successfully
# 2026-03-16 17:42:10,435 - INFO - root - Batch 7 - sent 500 records successfully
# 2026-03-16 17:42:10,878 - INFO - root - Batch 8 - sent 500 records successfully
# 2026-03-16 17:42:11,325 - INFO - root - Batch 9 - sent 500 records successfully
# 2026-03-16 17:42:11,743 - INFO - root - Batch 10 - sent 500 records successfully
# 2026-03-16 17:42:12,154 - INFO - root - Batch 11 - sent 500 records successfully
# 2026-03-16 17:42:12,592 - INFO - root - Batch 12 - sent 500 records successfully
# 2026-03-16 17:42:13,086 - INFO - root - Batch 13 - sent 500 records successfully
# 2026-03-16 17:42:13,548 - INFO - root - Batch 14 - sent 500 records successfully
# 2026-03-16 17:42:14,031 - INFO - root - Batch 15 - sent 500 records successfully
# 2026-03-16 17:42:14,471 - INFO - root - Batch 16 - sent 500 records successfully
# 2026-03-16 17:42:14,773 - INFO - root - Batch 17 - sent 425 records successfully
# 2026-03-16 17:42:14,777 - INFO - root - Finished sending 8925 states to Kinesis (batched)
# 2026-03-16 17:42:15,763 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-16 17:42:18,053 - INFO - root - Retrieved 8911 state vectors from OpenSky API
# 2026-03-16 17:42:18,153 - INFO - root - Sending 8911 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-16 17:42:18,764 - INFO - root - Batch 0 - sent 500 records successfully
# 2026-03-16 17:42:19,173 - INFO - root - Batch 1 - sent 500 records successfully
# 2026-03-16 17:42:19,598 - INFO - root - Batch 2 - sent 500 records successfully
# 2026-03-16 17:42:20,015 - INFO - root - Batch 3 - sent 500 records successfully
# 2026-03-16 17:42:20,435 - INFO - root - Batch 4 - sent 500 records successfully
# 2026-03-16 17:42:20,999 - INFO - root - Batch 5 - sent 500 records successfully
# 2026-03-16 17:42:21,422 - INFO - root - Batch 6 - sent 500 records successfully
# 2026-03-16 17:42:21,996 - INFO - root - Batch 7 - sent 500 records successfully
# 2026-03-16 17:42:22,424 - INFO - root - Batch 8 - sent 500 records successfully
# 2026-03-16 17:42:22,852 - INFO - root - Batch 9 - sent 500 records successfully
# 2026-03-16 17:42:23,285 - INFO - root - Batch 10 - sent 500 records successfully
# 2026-03-16 17:42:23,835 - INFO - root - Batch 11 - sent 500 records successfully
# 2026-03-16 17:42:24,269 - INFO - root - Batch 12 - sent 500 records successfully
# 2026-03-16 17:42:24,689 - INFO - root - Batch 13 - sent 500 records successfully
# 2026-03-16 17:42:25,124 - INFO - root - Batch 14 - sent 500 records successfully
# 2026-03-16 17:42:25,574 - INFO - root - Batch 15 - sent 500 records successfully
# 2026-03-16 17:42:26,010 - INFO - root - Batch 16 - sent 500 records successfully
# 2026-03-16 17:42:26,427 - INFO - root - Batch 17 - sent 411 records successfully
# 2026-03-16 17:42:26,432 - INFO - root - Finished sending 8911 states to Kinesis (batched)
# 2026-03-16 17:42:27,451 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-16 17:42:29,907 - INFO - root - Retrieved 8920 state vectors from OpenSky API
# 2026-03-16 17:42:30,042 - INFO - root - Sending 8920 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-16 17:42:30,686 - INFO - root - Batch 0 - sent 500 records successfully
# 2026-03-16 17:42:31,109 - INFO - root - Batch 1 - sent 500 records successfully
# 2026-03-16 17:42:31,572 - INFO - root - Batch 2 - sent 500 records successfully
# 2026-03-16 17:42:32,023 - INFO - root - Batch 3 - sent 500 records successfully
# 2026-03-16 17:42:33,357 - INFO - root - Batch 4 - sent 500 records successfully
# 2026-03-16 17:42:34,208 - INFO - root - Batch 5 - sent 500 records successfully
# 2026-03-16 17:42:34,774 - INFO - root - Batch 6 - sent 500 records successfully
# 2026-03-16 17:42:35,408 - INFO - root - Batch 7 - sent 500 records successfully
# 2026-03-16 17:42:35,998 - INFO - root - Batch 8 - sent 500 records successfully
# 2026-03-16 17:42:36,547 - INFO - root - Batch 9 - sent 500 records successfully
# 2026-03-16 17:42:37,088 - INFO - root - Batch 10 - sent 500 records successfully
# 2026-03-16 17:42:37,526 - INFO - root - Batch 11 - sent 500 records successfully
# 2026-03-16 17:42:37,963 - INFO - root - Batch 12 - sent 500 records successfully
# 2026-03-16 17:42:38,399 - INFO - root - Batch 13 - sent 500 records successfully
# 2026-03-16 17:42:38,825 - INFO - root - Batch 14 - sent 500 records successfully
# 2026-03-16 17:42:39,244 - INFO - root - Batch 15 - sent 500 records successfully
# 2026-03-16 17:42:39,674 - INFO - root - Batch 16 - sent 500 records successfully
# 2026-03-16 17:42:40,254 - INFO - root - Batch 17 - sent 420 records successfully
# 2026-03-16 17:42:40,258 - INFO - root - Finished sending 8920 states to Kinesis (batched)
# 2026-03-16 17:42:41,303 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-16 17:42:44,708 - INFO - root - Retrieved 8921 state vectors from OpenSky API
# 2026-03-16 17:42:44,812 - INFO - root - Sending 8921 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-16 17:42:45,517 - INFO - root - Batch 0 - sent 500 records successfully
# 2026-03-16 17:42:45,960 - INFO - root - Batch 1 - sent 500 records successfully
# 2026-03-16 17:42:46,694 - INFO - root - Batch 2 - sent 500 records successfully
# 2026-03-16 17:42:47,260 - INFO - root - Batch 3 - sent 500 records successfully
# 2026-03-16 17:42:47,857 - INFO - root - Batch 4 - sent 500 records successfully
# 2026-03-16 17:42:48,419 - INFO - root - Batch 5 - sent 500 records successfully
# 2026-03-16 17:42:48,980 - INFO - root - Batch 6 - sent 500 records successfully
# 2026-03-16 17:42:49,535 - INFO - root - Batch 7 - sent 500 records successfully
# 2026-03-16 17:42:50,121 - INFO - root - Batch 8 - sent 500 records successfully
# 2026-03-16 17:42:50,681 - INFO - root - Batch 9 - sent 500 records successfully
# 2026-03-16 17:42:51,246 - INFO - root - Batch 10 - sent 500 records successfully
# 2026-03-16 17:42:51,667 - INFO - root - Batch 11 - sent 500 records successfully
# 2026-03-16 17:42:52,125 - INFO - root - Batch 12 - sent 500 records successfully
# 2026-03-16 17:42:52,569 - INFO - root - Batch 13 - sent 500 records successfully
# 2026-03-16 17:42:53,056 - INFO - root - Batch 14 - sent 500 records successfully
# 2026-03-16 17:42:53,764 - INFO - root - Batch 15 - sent 500 records successfully
# 2026-03-16 17:42:54,444 - INFO - root - Batch 16 - sent 500 records successfully
# 2026-03-16 17:42:54,962 - INFO - root - Batch 17 - sent 421 records successfully
# 2026-03-16 17:42:54,964 - INFO - root - Finished sending 8921 states to Kinesis (batched)
# 2026-03-16 17:42:55,979 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-16 17:42:58,203 - INFO - root - Retrieved 8921 state vectors from OpenSky API
# 2026-03-16 17:42:58,284 - INFO - root - Sending 8921 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-16 17:42:59,014 - INFO - root - Batch 0 - sent 500 records successfully
# 2026-03-16 17:42:59,760 - INFO - root - Batch 1 - sent 500 records successfully
# 2026-03-16 17:43:00,310 - INFO - root - Batch 2 - sent 500 records successfully
# 2026-03-16 17:43:00,854 - INFO - root - Batch 3 - sent 500 records successfully
# 2026-03-16 17:43:01,399 - INFO - root - Batch 4 - sent 500 records successfully
# 2026-03-16 17:43:01,946 - INFO - root - Batch 5 - sent 500 records successfully
# 2026-03-16 17:43:02,399 - INFO - root - Batch 6 - sent 500 records successfully
# 2026-03-16 17:43:03,058 - INFO - root - Batch 7 - sent 500 records successfully
# 2026-03-16 17:43:03,688 - INFO - root - Batch 8 - sent 500 records successfully
# 2026-03-16 17:43:04,141 - INFO - root - Batch 9 - sent 500 records successfully
# 2026-03-16 17:43:04,738 - INFO - root - Batch 10 - sent 500 records successfully
# 2026-03-16 17:43:05,191 - INFO - root - Batch 11 - sent 500 records successfully
# 2026-03-16 17:43:05,623 - INFO - root - Batch 12 - sent 500 records successfully
# 2026-03-16 17:43:06,064 - INFO - root - Batch 13 - sent 500 records successfully
# 2026-03-16 17:43:06,909 - INFO - root - Batch 14 - sent 500 records successfully
# 2026-03-16 17:43:07,347 - INFO - root - Batch 15 - sent 500 records successfully
# 2026-03-16 17:43:07,806 - INFO - root - Batch 16 - sent 500 records successfully
# 2026-03-16 17:43:08,255 - INFO - root - Batch 17 - sent 421 records successfully
# 2026-03-16 17:43:08,257 - INFO - root - Finished sending 8921 states to Kinesis (batched)
# 2026-03-16 17:43:09,284 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-16 17:43:11,795 - INFO - root - Retrieved 8932 state vectors from OpenSky API
# 2026-03-16 17:43:11,874 - INFO - root - Sending 8932 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-16 17:43:12,530 - INFO - root - Batch 0 - sent 500 records successfully
# 2026-03-16 17:43:12,988 - INFO - root - Batch 1 - sent 500 records successfully
# 2026-03-16 17:43:13,449 - INFO - root - Batch 2 - sent 500 records successfully
# 2026-03-16 17:43:13,970 - INFO - root - Batch 3 - sent 500 records successfully
# 2026-03-16 17:43:14,416 - INFO - root - Batch 4 - sent 500 records successfully
# 2026-03-16 17:43:14,854 - INFO - root - Batch 5 - sent 500 records successfully
# 2026-03-16 17:43:15,267 - INFO - root - Batch 6 - sent 500 records successfully
# 2026-03-16 17:43:15,671 - INFO - root - Batch 7 - sent 500 records successfully
# 2026-03-16 17:43:16,080 - INFO - root - Batch 8 - sent 500 records successfully
# 2026-03-16 17:43:16,492 - INFO - root - Batch 9 - sent 500 records successfully
# 2026-03-16 17:43:16,806 - INFO - root - Batch 10 - sent 500 records successfully
# 2026-03-16 17:43:17,100 - INFO - root - Batch 11 - sent 500 records successfully
# 2026-03-16 17:43:17,389 - INFO - root - Batch 12 - sent 500 records successfully
# 2026-03-16 17:43:18,022 - INFO - root - Batch 13 - sent 500 records successfully
# 2026-03-16 17:43:18,446 - INFO - root - Batch 14 - sent 500 records successfully
# 2026-03-16 17:43:18,877 - INFO - root - Batch 15 - sent 500 records successfully
# 2026-03-16 17:43:19,293 - INFO - root - Batch 16 - sent 500 records successfully
# 2026-03-16 17:43:19,704 - INFO - root - Batch 17 - sent 432 records successfully
# 2026-03-16 17:43:19,706 - INFO - root - Finished sending 8932 states to Kinesis (batched)
# 2026-03-16 17:43:20,740 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-16 17:43:23,081 - INFO - root - Retrieved 8940 state vectors from OpenSky API
# 2026-03-16 17:43:23,175 - INFO - root - Sending 8940 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-16 17:43:24,140 - INFO - root - Batch 0 - sent 500 records successfully
# 2026-03-16 17:43:24,556 - INFO - root - Batch 1 - sent 500 records successfully
# 2026-03-16 17:43:24,991 - INFO - root - Batch 2 - sent 500 records successfully
# 2026-03-16 17:43:25,425 - INFO - root - Batch 3 - sent 500 records successfully
# 2026-03-16 17:43:26,079 - INFO - root - Batch 4 - sent 500 records successfully
# 2026-03-16 17:43:26,529 - INFO - root - Batch 5 - sent 500 records successfully
# 2026-03-16 17:43:26,978 - INFO - root - Batch 6 - sent 500 records successfully
# 2026-03-16 17:43:27,577 - INFO - root - Batch 7 - sent 500 records successfully
# 2026-03-16 17:43:28,032 - INFO - root - Batch 8 - sent 500 records successfully
# 2026-03-16 17:43:28,467 - INFO - root - Batch 9 - sent 500 records successfully
# 2026-03-16 17:43:28,911 - INFO - root - Batch 10 - sent 500 records successfully
# 2026-03-16 17:43:29,345 - INFO - root - Batch 11 - sent 500 records successfully
# 2026-03-16 17:43:29,781 - INFO - root - Batch 12 - sent 500 records successfully
# 2026-03-16 17:43:30,225 - INFO - root - Batch 13 - sent 500 records successfully
# 2026-03-16 17:43:30,694 - INFO - root - Batch 14 - sent 500 records successfully
# 2026-03-16 17:43:31,159 - INFO - root - Batch 15 - sent 500 records successfully
# 2026-03-16 17:43:31,611 - INFO - root - Batch 16 - sent 500 records successfully
# 2026-03-16 17:43:32,017 - INFO - root - Batch 17 - sent 440 records successfully
# 2026-03-16 17:43:32,021 - INFO - root - Finished sending 8940 states to Kinesis (batched)
# 2026-03-16 17:43:32,984 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-16 17:43:35,230 - INFO - root - Retrieved 8939 state vectors from OpenSky API
# 2026-03-16 17:43:35,315 - INFO - root - Sending 8939 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-16 17:43:35,950 - INFO - root - Batch 0 - sent 500 records successfully
# 2026-03-16 17:43:36,378 - INFO - root - Batch 1 - sent 500 records successfully
# 2026-03-16 17:43:36,795 - INFO - root - Batch 2 - sent 500 records successfully
# 2026-03-16 17:43:37,197 - INFO - root - Batch 3 - sent 500 records successfully
# 2026-03-16 17:43:37,617 - INFO - root - Batch 4 - sent 500 records successfully
# 2026-03-16 17:43:38,029 - INFO - root - Batch 5 - sent 500 records successfully
# 2026-03-16 17:43:38,433 - INFO - root - Batch 6 - sent 500 records successfully
# 2026-03-16 17:43:38,849 - INFO - root - Batch 7 - sent 500 records successfully
# 2026-03-16 17:43:39,268 - INFO - root - Batch 8 - sent 500 records successfully
# 2026-03-16 17:43:39,700 - INFO - root - Batch 9 - sent 500 records successfully
# 2026-03-16 17:43:40,179 - INFO - root - Batch 10 - sent 500 records successfully
# 2026-03-16 17:43:40,648 - INFO - root - Batch 11 - sent 500 records successfully
# 2026-03-16 17:43:41,072 - INFO - root - Batch 12 - sent 500 records successfully
# 2026-03-16 17:43:41,503 - INFO - root - Batch 13 - sent 500 records successfully
# 2026-03-16 17:43:41,933 - INFO - root - Batch 14 - sent 500 records successfully
# 2026-03-16 17:43:42,398 - INFO - root - Batch 15 - sent 500 records successfully
# 2026-03-16 17:43:42,814 - INFO - root - Batch 16 - sent 500 records successfully
# 2026-03-16 17:43:43,102 - INFO - root - Batch 17 - sent 439 records successfully
# 2026-03-16 17:43:43,104 - INFO - root - Finished sending 8939 states to Kinesis (batched)
# 2026-03-16 17:43:44,033 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-16 17:43:46,526 - INFO - root - Retrieved 8932 state vectors from OpenSky API
# 2026-03-16 17:43:46,626 - INFO - root - Sending 8932 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-16 17:43:47,230 - INFO - root - Batch 0 - sent 500 records successfully
# 2026-03-16 17:43:47,638 - INFO - root - Batch 1 - sent 500 records successfully
# 2026-03-16 17:43:48,065 - INFO - root - Batch 2 - sent 500 records successfully
# 2026-03-16 17:43:48,456 - INFO - root - Batch 3 - sent 500 records successfully
# 2026-03-16 17:43:48,880 - INFO - root - Batch 4 - sent 500 records successfully
# 2026-03-16 17:43:49,267 - INFO - root - Batch 5 - sent 500 records successfully
# 2026-03-16 17:43:49,694 - INFO - root - Batch 6 - sent 500 records successfully
# 2026-03-16 17:43:50,111 - INFO - root - Batch 7 - sent 500 records successfully
# 2026-03-16 17:43:50,835 - INFO - root - Batch 8 - sent 500 records successfully
# 2026-03-16 17:43:51,261 - INFO - root - Batch 9 - sent 500 records successfully
# 2026-03-16 17:43:51,714 - INFO - root - Batch 10 - sent 500 records successfully
# 2026-03-16 17:43:52,134 - INFO - root - Batch 11 - sent 500 records successfully
# 2026-03-16 17:43:52,568 - INFO - root - Batch 12 - sent 500 records successfully
# 2026-03-16 17:43:53,002 - INFO - root - Batch 13 - sent 500 records successfully
# 2026-03-16 17:43:53,434 - INFO - root - Batch 14 - sent 500 records successfully
# 2026-03-16 17:43:53,871 - INFO - root - Batch 15 - sent 500 records successfully
# 2026-03-16 17:43:54,298 - INFO - root - Batch 16 - sent 500 records successfully
# 2026-03-16 17:43:54,588 - INFO - root - Batch 17 - sent 432 records successfully
# 2026-03-16 17:43:54,589 - INFO - root - Finished sending 8932 states to Kinesis (batched)
# 2026-03-16 17:43:55,573 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-16 17:43:57,871 - INFO - root - Retrieved 8942 state vectors from OpenSky API
# 2026-03-16 17:43:57,957 - INFO - root - Sending 8942 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-16 17:43:58,737 - INFO - root - Batch 0 - sent 500 records successfully
# 2026-03-16 17:43:59,405 - INFO - root - Batch 1 - sent 500 records successfully
# 2026-03-16 17:43:59,970 - INFO - root - Batch 2 - sent 500 records successfully
# 2026-03-16 17:44:00,517 - INFO - root - Batch 3 - sent 500 records successfully
# 2026-03-16 17:44:01,067 - INFO - root - Batch 4 - sent 500 records successfully
# 2026-03-16 17:44:01,625 - INFO - root - Batch 5 - sent 500 records successfully
# 2026-03-16 17:44:02,165 - INFO - root - Batch 6 - sent 500 records successfully
# 2026-03-16 17:44:02,754 - INFO - root - Batch 7 - sent 500 records successfully
# 2026-03-16 17:44:03,182 - INFO - root - Batch 8 - sent 500 records successfully
# 2026-03-16 17:44:03,609 - INFO - root - Batch 9 - sent 500 records successfully
# 2026-03-16 17:44:04,475 - INFO - root - Batch 10 - sent 500 records successfully
# 2026-03-16 17:44:05,054 - INFO - root - Batch 11 - sent 500 records successfully
# 2026-03-16 17:44:06,978 - INFO - root - Batch 12 - sent 500 records successfully
# 2026-03-16 17:44:07,728 - INFO - root - Batch 13 - sent 500 records successfully
# 2026-03-16 17:44:08,490 - INFO - root - Batch 14 - sent 500 records successfully
# 2026-03-16 17:44:09,225 - INFO - root - Batch 15 - sent 500 records successfully
# 2026-03-16 17:44:09,871 - INFO - root - Batch 16 - sent 500 records successfully
# 2026-03-16 17:44:10,489 - INFO - root - Batch 17 - sent 442 records successfully
# 2026-03-16 17:44:10,492 - INFO - root - Finished sending 8942 states to Kinesis (batched)
# 2026-03-16 17:44:11,473 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-16 17:44:13,861 - INFO - root - Retrieved 8936 state vectors from OpenSky API
# 2026-03-16 17:44:13,940 - INFO - root - Sending 8936 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-16 17:44:14,992 - INFO - root - Batch 0 - sent 500 records successfully
# 2026-03-16 17:44:15,763 - INFO - root - Batch 1 - sent 500 records successfully
# 2026-03-16 17:44:16,535 - INFO - root - Batch 2 - sent 500 records successfully
# 2026-03-16 17:44:17,297 - INFO - root - Batch 3 - sent 500 records successfully
# 2026-03-16 17:44:18,023 - INFO - root - Batch 4 - sent 500 records successfully
# 2026-03-16 17:44:18,750 - INFO - root - Batch 5 - sent 500 records successfully
# 2026-03-16 17:44:19,482 - INFO - root - Batch 6 - sent 500 records successfully
# 2026-03-16 17:44:20,339 - INFO - root - Batch 7 - sent 500 records successfully
# 2026-03-16 17:44:21,338 - INFO - root - Batch 8 - sent 500 records successfully
# 2026-03-16 17:44:22,330 - INFO - root - Batch 9 - sent 500 records successfully
# 2026-03-16 17:44:23,443 - INFO - root - Batch 10 - sent 500 records successfully
# 2026-03-16 17:44:24,566 - INFO - root - Batch 11 - sent 500 records successfully
# 2026-03-16 17:44:25,571 - INFO - root - Batch 12 - sent 500 records successfully
# 2026-03-16 17:44:26,951 - INFO - root - Batch 13 - sent 500 records successfully
# 2026-03-16 17:44:28,197 - INFO - root - Batch 14 - sent 500 records successfully
# 2026-03-16 17:44:29,318 - INFO - root - Batch 15 - sent 500 records successfully
# 2026-03-16 17:44:30,468 - INFO - root - Batch 16 - sent 500 records successfully
# 2026-03-16 17:44:31,326 - INFO - root - Batch 17 - sent 436 records successfully
# 2026-03-16 17:44:31,330 - INFO - root - Finished sending 8936 states to Kinesis (batched)
# 2026-03-16 17:44:32,316 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-16 17:44:34,565 - INFO - root - Retrieved 8930 state vectors from OpenSky API
# 2026-03-16 17:44:34,633 - INFO - root - Sending 8930 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-16 17:44:35,983 - INFO - root - Batch 0 - sent 500 records successfully
# 2026-03-16 17:44:37,227 - INFO - root - Batch 1 - sent 500 records successfully
# 2026-03-16 17:44:38,228 - INFO - root - Batch 2 - sent 500 records successfully
# 2026-03-16 17:44:39,220 - INFO - root - Batch 3 - sent 500 records successfully
# 2026-03-16 17:44:40,204 - INFO - root - Batch 4 - sent 500 records successfully
# 2026-03-16 17:44:41,203 - INFO - root - Batch 5 - sent 500 records successfully
# 2026-03-16 17:44:42,169 - INFO - root - Batch 6 - sent 500 records successfully
# 2026-03-16 17:44:43,049 - INFO - root - Batch 7 - sent 500 records successfully
# 2026-03-16 17:44:43,928 - INFO - root - Batch 8 - sent 500 records successfully
# 2026-03-16 17:44:44,783 - INFO - root - Batch 9 - sent 500 records successfully
# 2026-03-16 17:44:45,639 - INFO - root - Batch 10 - sent 500 records successfully
# 2026-03-16 17:44:46,497 - INFO - root - Batch 11 - sent 500 records successfully
# 2026-03-16 17:44:47,274 - INFO - root - Batch 12 - sent 500 records successfully
# 2026-03-16 17:44:48,018 - INFO - root - Batch 13 - sent 500 records successfully
# 2026-03-16 17:44:48,738 - INFO - root - Batch 14 - sent 500 records successfully
# 2026-03-16 17:44:49,369 - INFO - root - Batch 15 - sent 500 records successfully
# 2026-03-16 17:44:49,923 - INFO - root - Batch 16 - sent 500 records successfully
# 2026-03-16 17:44:50,411 - INFO - root - Batch 17 - sent 430 records successfully
# 2026-03-16 17:44:50,416 - INFO - root - Finished sending 8930 states to Kinesis (batched)
# 2026-03-16 17:44:51,456 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-16 17:44:54,021 - INFO - root - Retrieved 8944 state vectors from OpenSky API
# 2026-03-16 17:44:54,095 - INFO - root - Sending 8944 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-16 17:44:54,810 - INFO - root - Batch 0 - sent 500 records successfully
# 2026-03-16 17:44:55,295 - INFO - root - Batch 1 - sent 500 records successfully
# 2026-03-16 17:44:55,801 - INFO - root - Batch 2 - sent 500 records successfully
# 2026-03-16 17:44:56,279 - INFO - root - Batch 3 - sent 500 records successfully
# 2026-03-16 17:44:56,761 - INFO - root - Batch 4 - sent 500 records successfully
# 2026-03-16 17:44:57,247 - INFO - root - Batch 5 - sent 500 records successfully
# 2026-03-16 17:44:57,697 - INFO - root - Batch 6 - sent 500 records successfully
# 2026-03-16 17:44:58,129 - INFO - root - Batch 7 - sent 500 records successfully
# 2026-03-16 17:44:58,573 - INFO - root - Batch 8 - sent 500 records successfully
# 2026-03-16 17:44:59,009 - INFO - root - Batch 9 - sent 500 records successfully
# 2026-03-16 17:44:59,450 - INFO - root - Batch 10 - sent 500 records successfully
# 2026-03-16 17:44:59,905 - INFO - root - Batch 11 - sent 500 records successfully
# 2026-03-16 17:45:00,315 - INFO - root - Batch 12 - sent 500 records successfully
# 2026-03-16 17:45:00,753 - INFO - root - Batch 13 - sent 500 records successfully
# 2026-03-16 17:45:01,109 - INFO - root - Batch 14 - sent 500 records successfully
# 2026-03-16 17:45:01,423 - INFO - root - Batch 15 - sent 500 records successfully
# 2026-03-16 17:45:01,742 - INFO - root - Batch 16 - sent 500 records successfully
# 2026-03-16 17:45:02,046 - INFO - root - Batch 17 - sent 444 records successfully
# 2026-03-16 17:45:02,049 - INFO - root - Finished sending 8944 states to Kinesis (batched)
# 2026-03-16 17:45:03,059 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-16 17:45:05,444 - INFO - root - Retrieved 8933 state vectors from OpenSky API
# 2026-03-16 17:45:05,517 - INFO - root - Sending 8933 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-16 17:45:06,161 - INFO - root - Batch 0 - sent 500 records successfully
# 2026-03-16 17:45:06,479 - INFO - root - Batch 1 - sent 500 records successfully
# 2026-03-16 17:45:06,801 - INFO - root - Batch 2 - sent 500 records successfully
# 2026-03-16 17:45:07,116 - INFO - root - Batch 3 - sent 500 records successfully
# 2026-03-16 17:45:07,447 - INFO - root - Batch 4 - sent 500 records successfully
# 2026-03-16 17:45:07,780 - INFO - root - Batch 5 - sent 500 records successfully
# 2026-03-16 17:45:08,119 - INFO - root - Batch 6 - sent 500 records successfully
# 2026-03-16 17:45:08,433 - INFO - root - Batch 7 - sent 500 records successfully
# 2026-03-16 17:45:08,750 - INFO - root - Batch 8 - sent 500 records successfully
# 2026-03-16 17:45:09,101 - INFO - root - Batch 9 - sent 500 records successfully
# 2026-03-16 17:45:09,409 - INFO - root - Batch 10 - sent 500 records successfully
# 2026-03-16 17:45:09,726 - INFO - root - Batch 11 - sent 500 records successfully
# 2026-03-16 17:45:10,191 - INFO - root - Batch 12 - sent 500 records successfully
# 2026-03-16 17:45:10,818 - INFO - root - Batch 13 - sent 500 records successfully
# 2026-03-16 17:45:11,282 - INFO - root - Batch 14 - sent 500 records successfully
# 2026-03-16 17:45:11,715 - INFO - root - Batch 15 - sent 500 records successfully
# 2026-03-16 17:45:12,157 - INFO - root - Batch 16 - sent 500 records successfully
# 2026-03-16 17:45:12,460 - INFO - root - Batch 17 - sent 433 records successfully
# 2026-03-16 17:45:12,462 - INFO - root - Finished sending 8933 states to Kinesis (batched)
# 2026-03-16 17:45:13,502 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-16 17:45:16,162 - INFO - root - Retrieved 8932 state vectors from OpenSky API
# 2026-03-16 17:45:16,251 - INFO - root - Sending 8932 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-16 17:45:16,891 - INFO - root - Batch 0 - sent 500 records successfully
# 2026-03-16 17:45:17,320 - INFO - root - Batch 1 - sent 500 records successfully
# 2026-03-16 17:45:17,749 - INFO - root - Batch 2 - sent 500 records successfully
# 2026-03-16 17:45:18,165 - INFO - root - Batch 3 - sent 500 records successfully
# 2026-03-16 17:45:18,650 - INFO - root - Batch 4 - sent 500 records successfully
# 2026-03-16 17:45:19,092 - INFO - root - Batch 5 - sent 500 records successfully
# 2026-03-16 17:45:19,534 - INFO - root - Batch 6 - sent 500 records successfully
# 2026-03-16 17:45:19,962 - INFO - root - Batch 7 - sent 500 records successfully
# 2026-03-16 17:45:20,369 - INFO - root - Batch 8 - sent 500 records successfully
# 2026-03-16 17:45:20,776 - INFO - root - Batch 9 - sent 500 records successfully
# 2026-03-16 17:45:21,208 - INFO - root - Batch 10 - sent 500 records successfully
# 2026-03-16 17:45:21,618 - INFO - root - Batch 11 - sent 500 records successfully
# 2026-03-16 17:45:22,005 - INFO - root - Batch 12 - sent 500 records successfully
# 2026-03-16 17:45:22,401 - INFO - root - Batch 13 - sent 500 records successfully
# 2026-03-16 17:45:22,816 - INFO - root - Batch 14 - sent 500 records successfully
# 2026-03-16 17:45:23,209 - INFO - root - Batch 15 - sent 500 records successfully
# 2026-03-16 17:45:23,614 - INFO - root - Batch 16 - sent 500 records successfully
# 2026-03-16 17:45:23,880 - INFO - root - Batch 17 - sent 432 records successfully
# 2026-03-16 17:45:23,883 - INFO - root - Finished sending 8932 states to Kinesis (batched)
# 2026-03-16 17:45:24,809 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-16 17:45:26,933 - INFO - root - Retrieved 8934 state vectors from OpenSky API
# 2026-03-16 17:45:26,996 - INFO - root - Sending 8934 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-16 17:45:27,579 - INFO - root - Batch 0 - sent 500 records successfully
# 2026-03-16 17:45:27,991 - INFO - root - Batch 1 - sent 500 records successfully
# 2026-03-16 17:45:28,418 - INFO - root - Batch 2 - sent 500 records successfully
# 2026-03-16 17:45:28,820 - INFO - root - Batch 3 - sent 500 records successfully
# 2026-03-16 17:45:29,229 - INFO - root - Batch 4 - sent 500 records successfully
# 2026-03-16 17:45:29,678 - INFO - root - Batch 5 - sent 500 records successfully
# 2026-03-16 17:45:30,147 - INFO - root - Batch 6 - sent 500 records successfully
# 2026-03-16 17:45:30,456 - INFO - root - Batch 7 - sent 500 records successfully
# 2026-03-16 17:45:30,754 - INFO - root - Batch 8 - sent 500 records successfully
# 2026-03-16 17:45:31,070 - INFO - root - Batch 9 - sent 500 records successfully
# 2026-03-16 17:45:31,384 - INFO - root - Batch 10 - sent 500 records successfully
# 2026-03-16 17:45:31,691 - INFO - root - Batch 11 - sent 500 records successfully
# 2026-03-16 17:45:32,015 - INFO - root - Batch 12 - sent 500 records successfully
# 2026-03-16 17:45:32,365 - INFO - root - Batch 13 - sent 500 records successfully
# 2026-03-16 17:45:32,702 - INFO - root - Batch 14 - sent 500 records successfully
# 2026-03-16 17:45:33,014 - INFO - root - Batch 15 - sent 500 records successfully
# 2026-03-16 17:45:33,329 - INFO - root - Batch 16 - sent 500 records successfully
# 2026-03-16 17:45:33,853 - INFO - root - Batch 17 - sent 434 records successfully
# 2026-03-16 17:45:33,857 - INFO - root - Finished sending 8934 states to Kinesis (batched)
# 2026-03-16 17:45:34,878 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-16 17:45:37,149 - INFO - root - Retrieved 8932 state vectors from OpenSky API
# 2026-03-16 17:45:37,217 - INFO - root - Sending 8932 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-16 17:45:37,845 - INFO - root - Batch 0 - sent 500 records successfully
# 2026-03-16 17:45:38,257 - INFO - root - Batch 1 - sent 500 records successfully
# 2026-03-16 17:45:38,576 - INFO - root - Batch 2 - sent 500 records successfully
# 2026-03-16 17:45:38,866 - INFO - root - Batch 3 - sent 500 records successfully
# 2026-03-16 17:45:39,173 - INFO - root - Batch 4 - sent 500 records successfully
# 2026-03-16 17:45:39,478 - INFO - root - Batch 5 - sent 500 records successfully
# 2026-03-16 17:45:39,777 - INFO - root - Batch 6 - sent 500 records successfully
# 2026-03-16 17:45:40,111 - INFO - root - Batch 7 - sent 500 records successfully
# 2026-03-16 17:45:40,418 - INFO - root - Batch 8 - sent 500 records successfully
# 2026-03-16 17:45:40,720 - INFO - root - Batch 9 - sent 500 records successfully
# 2026-03-16 17:45:41,051 - INFO - root - Batch 10 - sent 500 records successfully
# 2026-03-16 17:45:41,529 - INFO - root - Batch 11 - sent 500 records successfully
# 2026-03-16 17:45:41,833 - INFO - root - Batch 12 - sent 500 records successfully
# 2026-03-16 17:45:42,119 - INFO - root - Batch 13 - sent 500 records successfully
# 2026-03-16 17:45:42,413 - INFO - root - Batch 14 - sent 500 records successfully
# 2026-03-16 17:45:42,693 - INFO - root - Batch 15 - sent 500 records successfully
# 2026-03-16 17:45:42,972 - INFO - root - Batch 16 - sent 500 records successfully
# 2026-03-16 17:45:43,241 - INFO - root - Batch 17 - sent 432 records successfully
# 2026-03-16 17:45:43,243 - INFO - root - Finished sending 8932 states to Kinesis (batched)
# 2026-03-16 17:45:44,190 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-16 17:45:46,400 - INFO - root - Retrieved 8922 state vectors from OpenSky API
# 2026-03-16 17:45:46,467 - INFO - root - Sending 8922 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-16 17:45:47,071 - INFO - root - Batch 0 - sent 500 records successfully
# 2026-03-16 17:45:47,888 - INFO - root - Batch 1 - sent 500 records successfully
# 2026-03-16 17:45:48,297 - INFO - root - Batch 2 - sent 500 records successfully
# 2026-03-16 17:45:48,706 - INFO - root - Batch 3 - sent 500 records successfully
# 2026-03-16 17:45:49,108 - INFO - root - Batch 4 - sent 500 records successfully
# 2026-03-16 17:45:49,548 - INFO - root - Batch 5 - sent 500 records successfully
# 2026-03-16 17:45:50,031 - INFO - root - Batch 6 - sent 500 records successfully
# 2026-03-16 17:45:50,483 - INFO - root - Batch 7 - sent 500 records successfully
# 2026-03-16 17:45:50,924 - INFO - root - Batch 8 - sent 500 records successfully
# 2026-03-16 17:45:51,241 - INFO - root - Batch 9 - sent 500 records successfully
# 2026-03-16 17:45:51,549 - INFO - root - Batch 10 - sent 500 records successfully
# 2026-03-16 17:45:51,876 - INFO - root - Batch 11 - sent 500 records successfully
# 2026-03-16 17:45:52,237 - INFO - root - Batch 12 - sent 500 records successfully
# 2026-03-16 17:45:52,552 - INFO - root - Batch 13 - sent 500 records successfully
# 2026-03-16 17:45:52,863 - INFO - root - Batch 14 - sent 500 records successfully
# 2026-03-16 17:45:53,348 - INFO - root - Batch 15 - sent 500 records successfully
# 2026-03-16 17:45:53,776 - INFO - root - Batch 16 - sent 500 records successfully
# 2026-03-16 17:45:54,185 - INFO - root - Batch 17 - sent 422 records successfully
# 2026-03-16 17:45:54,187 - INFO - root - Finished sending 8922 states to Kinesis (batched)
# 2026-03-16 17:45:55,140 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-16 17:45:57,324 - INFO - root - Retrieved 8927 state vectors from OpenSky API
# 2026-03-16 17:45:57,405 - INFO - root - Sending 8927 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-16 17:45:58,047 - INFO - root - Batch 0 - sent 500 records successfully
# 2026-03-16 17:45:58,486 - INFO - root - Batch 1 - sent 500 records successfully
# 2026-03-16 17:45:58,926 - INFO - root - Batch 2 - sent 500 records successfully
# 2026-03-16 17:45:59,828 - INFO - root - Batch 3 - sent 500 records successfully
# 2026-03-16 17:46:00,262 - INFO - root - Batch 4 - sent 500 records successfully
# 2026-03-16 17:46:00,705 - INFO - root - Batch 5 - sent 500 records successfully
# 2026-03-16 17:46:01,141 - INFO - root - Batch 6 - sent 500 records successfully
# 2026-03-16 17:46:01,590 - INFO - root - Batch 7 - sent 500 records successfully
# 2026-03-16 17:46:02,026 - INFO - root - Batch 8 - sent 500 records successfully
# 2026-03-16 17:46:02,588 - INFO - root - Batch 9 - sent 500 records successfully
# 2026-03-16 17:46:03,032 - INFO - root - Batch 10 - sent 500 records successfully
# 2026-03-16 17:46:03,474 - INFO - root - Batch 11 - sent 500 records successfully
# 2026-03-16 17:46:03,939 - INFO - root - Batch 12 - sent 500 records successfully
# 2026-03-16 17:46:04,395 - INFO - root - Batch 13 - sent 500 records successfully
# 2026-03-16 17:46:04,836 - INFO - root - Batch 14 - sent 500 records successfully
# 2026-03-16 17:46:05,270 - INFO - root - Batch 15 - sent 500 records successfully
# 2026-03-16 17:46:05,707 - INFO - root - Batch 16 - sent 500 records successfully
# 2026-03-16 17:46:05,999 - INFO - root - Batch 17 - sent 427 records successfully
# 2026-03-16 17:46:06,001 - INFO - root - Finished sending 8927 states to Kinesis (batched)
# 2026-03-16 17:46:06,937 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-16 17:46:09,155 - INFO - root - Retrieved 8922 state vectors from OpenSky API
# 2026-03-16 17:46:09,256 - INFO - root - Sending 8922 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-16 17:46:09,925 - INFO - root - Batch 0 - sent 500 records successfully
# 2026-03-16 17:46:10,354 - INFO - root - Batch 1 - sent 500 records successfully
# 2026-03-16 17:46:10,807 - INFO - root - Batch 2 - sent 500 records successfully
# 2026-03-16 17:46:11,234 - INFO - root - Batch 3 - sent 500 records successfully
# 2026-03-16 17:46:11,684 - INFO - root - Batch 4 - sent 500 records successfully
# 2026-03-16 17:46:12,122 - INFO - root - Batch 5 - sent 500 records successfully
# 2026-03-16 17:46:12,542 - INFO - root - Batch 6 - sent 500 records successfully
# 2026-03-16 17:46:12,969 - INFO - root - Batch 7 - sent 500 records successfully
# 2026-03-16 17:46:13,380 - INFO - root - Batch 8 - sent 500 records successfully
# 2026-03-16 17:46:13,788 - INFO - root - Batch 9 - sent 500 records successfully
# 2026-03-16 17:46:14,197 - INFO - root - Batch 10 - sent 500 records successfully
# 2026-03-16 17:46:14,633 - INFO - root - Batch 11 - sent 500 records successfully
# 2026-03-16 17:46:15,193 - INFO - root - Batch 12 - sent 500 records successfully
# 2026-03-16 17:46:15,614 - INFO - root - Batch 13 - sent 500 records successfully
# 2026-03-16 17:46:15,942 - INFO - root - Batch 14 - sent 500 records successfully
# 2026-03-16 17:46:16,281 - INFO - root - Batch 15 - sent 500 records successfully
# 2026-03-16 17:46:16,594 - INFO - root - Batch 16 - sent 500 records successfully
# 2026-03-16 17:46:16,887 - INFO - root - Batch 17 - sent 422 records successfully
# 2026-03-16 17:46:16,890 - INFO - root - Finished sending 8922 states to Kinesis (batched)
# 2026-03-16 17:46:17,886 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-16 17:46:20,165 - INFO - root - Retrieved 8908 state vectors from OpenSky API
# 2026-03-16 17:46:20,244 - INFO - root - Sending 8908 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-16 17:46:20,838 - INFO - root - Batch 0 - sent 500 records successfully
# 2026-03-16 17:46:21,271 - INFO - root - Batch 1 - sent 500 records successfully
# 2026-03-16 17:46:21,596 - INFO - root - Batch 2 - sent 500 records successfully
# 2026-03-16 17:46:21,910 - INFO - root - Batch 3 - sent 500 records successfully
# 2026-03-16 17:46:22,226 - INFO - root - Batch 4 - sent 500 records successfully
# 2026-03-16 17:46:22,525 - INFO - root - Batch 5 - sent 500 records successfully
# 2026-03-16 17:46:22,865 - INFO - root - Batch 6 - sent 500 records successfully
# 2026-03-16 17:46:23,181 - INFO - root - Batch 7 - sent 500 records successfully
# 2026-03-16 17:46:23,502 - INFO - root - Batch 8 - sent 500 records successfully
# 2026-03-16 17:46:23,819 - INFO - root - Batch 9 - sent 500 records successfully
# 2026-03-16 17:46:24,299 - INFO - root - Batch 10 - sent 500 records successfully
# 2026-03-16 17:46:24,701 - INFO - root - Batch 11 - sent 500 records successfully
# 2026-03-16 17:46:25,004 - INFO - root - Batch 12 - sent 500 records successfully
# 2026-03-16 17:46:25,282 - INFO - root - Batch 13 - sent 500 records successfully
# 2026-03-16 17:46:25,554 - INFO - root - Batch 14 - sent 500 records successfully
# 2026-03-16 17:46:25,832 - INFO - root - Batch 15 - sent 500 records successfully
# 2026-03-16 17:46:26,110 - INFO - root - Batch 16 - sent 500 records successfully
# 2026-03-16 17:46:26,364 - INFO - root - Batch 17 - sent 408 records successfully
# 2026-03-16 17:46:26,367 - INFO - root - Finished sending 8908 states to Kinesis (batched)
