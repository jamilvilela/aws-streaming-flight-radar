# %%
import os
import sys
import json
import logging
import boto3
import requests
from datetime import datetime
from dotenv import load_dotenv
from utils.models import StateVector

load_dotenv()

# AWS clients
secrets_client = boto3.client("secretsmanager")
kinesis_client = boto3.client("kinesis")

# OpenSky OAuth2 + API endpoints
OPENSKY_TOKEN_URL = (
    "https://auth.opensky-network.org/auth/realms/opensky-network/protocol/openid-connect/token"
)
OPENSKY_STATES_URL = "https://opensky-network.org/api/states/all"

# %%
# logging 

logger = logging.getLogger()
logger.setLevel(logging.INFO)

if not logger.handlers:
    handler = logging.StreamHandler(sys.stdout)
    formatter = logging.Formatter(
        "%(asctime)s - %(levelname)s - %(name)s - %(message)s"
    )
    handler.setFormatter(formatter)
    logger.addHandler(handler)

# %%
# opensky functions 

def _get_opensky_credentials_from_secret():
    """
    Lê client_id e client_secret do AWS Secrets Manager.

    Espera que o secret (apontado por OPENSKY_SECRET_ARN) tenha o formato:
    {
      "client_id": "xxxx",
      "client_secret": "yyyy"
    }
    """
    try:
        client_id = os.environ.get("OPENSKY_CLIENT_ID")
        client_secret = os.environ.get("OPENSKY_CLIENT_SECRET")
        if not client_id or not client_secret:
            logger.error("Credentials is missing in secret")
            return None, None
        return client_id, client_secret
    except Exception as e:
        logger.error(f"Error retrieving OpenSky credentials from Secrets Manager: {e}")
        return None, None

def get_opensky_access_token():
    """
    Autentica na OpenSky via OAuth2 Client Credentials e retorna o access_token (Bearer).
    """
    client_id, client_secret = _get_opensky_credentials_from_secret()
    if not client_id or not client_secret:
        return None

    data = {
        "grant_type": "client_credentials",
        "client_id": client_id,
        "client_secret": client_secret,
    }

    try:
        resp = requests.post(OPENSKY_TOKEN_URL, data=data, timeout=10)
        resp.raise_for_status()
        access_token = resp.json().get("access_token")
        if not access_token:
            logger.error("No access_token in OpenSky auth response")
            return None
        logger.info("Successfully obtained OpenSky access token")
        return access_token
    except requests.RequestException as e:
        logger.error(f"Error obtaining OpenSky access token: {e}")
        return None

def convert_states_response_to_json(states: list[StateVector]) -> dict:
    json_data = {
        "timestamp": datetime.now().isoformat(),
        "total_states": 0,
        "states": [],
    }
    for state in states:
        json_data["states"].append(state.to_dict())

    json_data["total_states"] = len(json_data["states"])
    return json_data

def send_states_to_kinesis(json_resultado: dict, batch_size: int = 500) -> bool:
    """
    Envia todos os estados para o Kinesis usando PutRecords em batch.

    Retorna True se todos forem enviados com sucesso, False caso haja falhas.
    """
    stream_name = os.environ.get("KINESIS_STREAM")
    if not stream_name:
        logger.error("KINESIS_STREAM environment variable not set")
        return False

    states = json_resultado["states"]
    if not states:
        logger.info("No states to send to Kinesis")
        return True

    logger.info(f"Sending {len(states)} states to Kinesis stream '{stream_name}' in batches of {batch_size}...")

    all_ok = True

    # Monta todos os records
    records = [
        {
            "Data": json.dumps(state),
            "PartitionKey": state.get("icao24") or "unknown",
        }
        for state in states
    ]

    # Envia em lotes de até 500 registros (limite do Kinesis PutRecords)
    for i in range(0, len(records), batch_size):
        batch = records[i : i + batch_size]
        try:
            response = kinesis_client.put_records(
                StreamName=stream_name,
                Records=batch,
            )
            failed = response.get("FailedRecordCount", 0)
            if failed > 0:
                all_ok = False
                logger.error(
                    f"Batch {i//batch_size} - {failed}/{len(batch)} records failed"
                )
            else:
                logger.info(
                    f"Batch {i//batch_size} - sent {len(batch)} records successfully"
                )
        except Exception as e:
            all_ok = False
            logger.error(f"Error sending batch {i//batch_size} to Kinesis: {e}")

    logger.info(f"Finished sending {len(states)} states to Kinesis (batched)")
    return all_ok


def get_opensky_states(access_token):
    """
    Chama o endpoint /api/states/all usando Bearer token e
    retorna uma lista de StateVector.
    """
    headers = {"Authorization": f"Bearer {access_token}"}

    try:
        resp = requests.get(OPENSKY_STATES_URL, headers=headers, timeout=15)
        resp.raise_for_status()
        body = resp.json()
    except requests.RequestException as e:
        logger.error(f"Error calling OpenSky states API: {e}")
        return []

    raw_states = body.get("states", []) or []
    states: list[StateVector] = []

    for row in raw_states:
        try:
            state = StateVector.from_api_response(row)
            states.append(state)
        except Exception as e:
            logger.warning(f"Failed to parse state vector: {e}")

    logger.info(f"Retrieved {len(states)} state vectors from OpenSky API")
    return states

# %%
from asyncio import sleep
duration = 180
dt_start = datetime.now().isoformat()

while True:
    access_token = get_opensky_access_token()
    states = get_opensky_states(access_token)
    json_resultado = convert_states_response_to_json(states)
    ok = send_states_to_kinesis(json_resultado)
    await sleep(45)
    elapsed = (datetime.now() - datetime.fromisoformat(dt_start)).total_seconds()
    if elapsed  > duration:
        break
# Out:
# 2026-03-03 22:26:00,597 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:26:02,583 - INFO - root - Retrieved 6910 state vectors from OpenSky API
# 2026-03-03 22:26:02,640 - INFO - root - Sending 6910 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:26:02,683 - INFO - root - Finished sending 6910 states to Kinesis (batched)
# C:\Users\jamli\AppData\Local\Temp\ipykernel_27888\3719969415.py:10: RuntimeWarning: coroutine 'sleep' was never awaited
#   sleep(45)
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# 2026-03-03 22:26:03,625 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:26:06,560 - INFO - root - Retrieved 6908 state vectors from OpenSky API
# 2026-03-03 22:26:06,614 - INFO - root - Sending 6908 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:26:06,665 - INFO - root - Finished sending 6908 states to Kinesis (batched)
# 2026-03-03 22:26:07,561 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:26:09,568 - INFO - root - Retrieved 6908 state vectors from OpenSky API
# 2026-03-03 22:26:09,619 - INFO - root - Sending 6908 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:26:09,668 - INFO - root - Finished sending 6908 states to Kinesis (batched)
# 2026-03-03 22:26:10,478 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:26:12,447 - INFO - root - Retrieved 6913 state vectors from OpenSky API
# 2026-03-03 22:26:12,499 - INFO - root - Sending 6913 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:26:12,548 - INFO - root - Finished sending 6913 states to Kinesis (batched)
# 2026-03-03 22:26:13,397 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:26:15,388 - INFO - root - Retrieved 6910 state vectors from OpenSky API
# 2026-03-03 22:26:15,431 - INFO - root - Sending 6910 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:26:15,480 - INFO - root - Finished sending 6910 states to Kinesis (batched)
# 2026-03-03 22:26:16,272 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:26:18,231 - INFO - root - Retrieved 6910 state vectors from OpenSky API
# 2026-03-03 22:26:18,278 - INFO - root - Sending 6910 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:26:18,322 - INFO - root - Finished sending 6910 states to Kinesis (batched)
# 2026-03-03 22:26:19,148 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:26:21,069 - INFO - root - Retrieved 6905 state vectors from OpenSky API
# 2026-03-03 22:26:21,120 - INFO - root - Sending 6905 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:26:21,166 - INFO - root - Finished sending 6905 states to Kinesis (batched)
# 2026-03-03 22:26:21,990 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:26:24,031 - INFO - root - Retrieved 6901 state vectors from OpenSky API
# 2026-03-03 22:26:24,074 - INFO - root - Sending 6901 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:26:24,117 - INFO - root - Finished sending 6901 states to Kinesis (batched)
# 2026-03-03 22:26:24,933 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:26:26,887 - INFO - root - Retrieved 6902 state vectors from OpenSky API
# 2026-03-03 22:26:26,927 - INFO - root - Sending 6902 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:26:26,976 - INFO - root - Finished sending 6902 states to Kinesis (batched)
# 2026-03-03 22:26:27,788 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:26:29,896 - INFO - root - Retrieved 6902 state vectors from OpenSky API
# 2026-03-03 22:26:29,956 - INFO - root - Sending 6902 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:26:30,006 - INFO - root - Finished sending 6902 states to Kinesis (batched)
# 2026-03-03 22:26:30,857 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:26:32,762 - INFO - root - Retrieved 6906 state vectors from OpenSky API
# 2026-03-03 22:26:32,806 - INFO - root - Sending 6906 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:26:32,844 - INFO - root - Finished sending 6906 states to Kinesis (batched)
# 2026-03-03 22:26:33,678 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:26:35,633 - INFO - root - Retrieved 6900 state vectors from OpenSky API
# 2026-03-03 22:26:35,677 - INFO - root - Sending 6900 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:26:35,717 - INFO - root - Finished sending 6900 states to Kinesis (batched)
# 2026-03-03 22:26:36,548 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:26:38,458 - INFO - root - Retrieved 6900 state vectors from OpenSky API
# 2026-03-03 22:26:38,516 - INFO - root - Sending 6900 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:26:38,570 - INFO - root - Finished sending 6900 states to Kinesis (batched)
# 2026-03-03 22:26:39,434 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:26:41,355 - INFO - root - Retrieved 6901 state vectors from OpenSky API
# 2026-03-03 22:26:41,411 - INFO - root - Sending 6901 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:26:41,464 - INFO - root - Finished sending 6901 states to Kinesis (batched)
# 2026-03-03 22:26:42,309 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:26:44,365 - INFO - root - Retrieved 6896 state vectors from OpenSky API
# 2026-03-03 22:26:44,411 - INFO - root - Sending 6896 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:26:44,462 - INFO - root - Finished sending 6896 states to Kinesis (batched)
# 2026-03-03 22:26:45,309 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:26:47,272 - INFO - root - Retrieved 6897 state vectors from OpenSky API
# 2026-03-03 22:26:47,329 - INFO - root - Sending 6897 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:26:47,374 - INFO - root - Finished sending 6897 states to Kinesis (batched)
# 2026-03-03 22:26:48,201 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:26:50,134 - INFO - root - Retrieved 6897 state vectors from OpenSky API
# 2026-03-03 22:26:50,230 - INFO - root - Sending 6897 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:26:50,286 - INFO - root - Finished sending 6897 states to Kinesis (batched)
# 2026-03-03 22:26:51,140 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:26:53,101 - INFO - root - Retrieved 6893 state vectors from OpenSky API
# 2026-03-03 22:26:53,196 - INFO - root - Sending 6893 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:26:53,237 - INFO - root - Finished sending 6893 states to Kinesis (batched)
# 2026-03-03 22:26:54,047 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:26:55,972 - INFO - root - Retrieved 6890 state vectors from OpenSky API
# 2026-03-03 22:26:56,021 - INFO - root - Sending 6890 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:26:56,074 - INFO - root - Finished sending 6890 states to Kinesis (batched)
# 2026-03-03 22:26:56,885 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:26:58,804 - INFO - root - Retrieved 6890 state vectors from OpenSky API
# 2026-03-03 22:26:58,853 - INFO - root - Sending 6890 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:26:58,901 - INFO - root - Finished sending 6890 states to Kinesis (batched)
# 2026-03-03 22:26:59,739 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:27:01,751 - INFO - root - Retrieved 6890 state vectors from OpenSky API
# 2026-03-03 22:27:01,853 - INFO - root - Sending 6890 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:27:01,955 - INFO - root - Finished sending 6890 states to Kinesis (batched)
# 2026-03-03 22:27:03,099 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:27:05,561 - INFO - root - Retrieved 6892 state vectors from OpenSky API
# 2026-03-03 22:27:05,612 - INFO - root - Sending 6892 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:27:05,661 - INFO - root - Finished sending 6892 states to Kinesis (batched)
# 2026-03-03 22:27:06,463 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:27:08,586 - INFO - root - Retrieved 6890 state vectors from OpenSky API
# 2026-03-03 22:27:08,630 - INFO - root - Sending 6890 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:27:08,674 - INFO - root - Finished sending 6890 states to Kinesis (batched)
# 2026-03-03 22:27:09,501 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:27:11,472 - INFO - root - Retrieved 6892 state vectors from OpenSky API
# 2026-03-03 22:27:11,521 - INFO - root - Sending 6892 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:27:11,564 - INFO - root - Finished sending 6892 states to Kinesis (batched)
# 2026-03-03 22:27:12,420 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:27:14,376 - INFO - root - Retrieved 6878 state vectors from OpenSky API
# 2026-03-03 22:27:14,419 - INFO - root - Sending 6878 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:27:14,460 - INFO - root - Finished sending 6878 states to Kinesis (batched)
# 2026-03-03 22:27:15,259 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:27:17,490 - INFO - root - Retrieved 6892 state vectors from OpenSky API
# 2026-03-03 22:27:17,539 - INFO - root - Sending 6892 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:27:17,582 - INFO - root - Finished sending 6892 states to Kinesis (batched)
# 2026-03-03 22:27:18,428 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:27:20,469 - INFO - root - Retrieved 6885 state vectors from OpenSky API
# 2026-03-03 22:27:20,513 - INFO - root - Sending 6885 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:27:20,557 - INFO - root - Finished sending 6885 states to Kinesis (batched)
# 2026-03-03 22:27:21,386 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:27:23,978 - INFO - root - Retrieved 6889 state vectors from OpenSky API
# 2026-03-03 22:27:24,021 - INFO - root - Sending 6889 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:27:24,063 - INFO - root - Finished sending 6889 states to Kinesis (batched)
# 2026-03-03 22:27:24,872 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:27:29,014 - INFO - root - Retrieved 6885 state vectors from OpenSky API
# 2026-03-03 22:27:29,060 - INFO - root - Sending 6885 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:27:29,102 - INFO - root - Finished sending 6885 states to Kinesis (batched)
# 2026-03-03 22:27:29,897 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:27:31,973 - INFO - root - Retrieved 6881 state vectors from OpenSky API
# 2026-03-03 22:27:32,018 - INFO - root - Sending 6881 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:27:32,061 - INFO - root - Finished sending 6881 states to Kinesis (batched)
# 2026-03-03 22:27:32,903 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:27:35,352 - INFO - root - Retrieved 6877 state vectors from OpenSky API
# 2026-03-03 22:27:35,406 - INFO - root - Sending 6877 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:27:35,508 - INFO - root - Finished sending 6877 states to Kinesis (batched)
# 2026-03-03 22:27:36,324 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:27:38,261 - INFO - root - Retrieved 6877 state vectors from OpenSky API
# 2026-03-03 22:27:38,304 - INFO - root - Sending 6877 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:27:38,348 - INFO - root - Finished sending 6877 states to Kinesis (batched)
# 2026-03-03 22:27:39,158 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:27:41,108 - INFO - root - Retrieved 6876 state vectors from OpenSky API
# 2026-03-03 22:27:41,152 - INFO - root - Sending 6876 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:27:41,199 - INFO - root - Finished sending 6876 states to Kinesis (batched)
# 2026-03-03 22:27:42,009 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:27:44,142 - INFO - root - Retrieved 6871 state vectors from OpenSky API
# 2026-03-03 22:27:44,191 - INFO - root - Sending 6871 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:27:44,241 - INFO - root - Finished sending 6871 states to Kinesis (batched)
# 2026-03-03 22:27:45,064 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:27:46,975 - INFO - root - Retrieved 6874 state vectors from OpenSky API
# 2026-03-03 22:27:47,020 - INFO - root - Sending 6874 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:27:47,062 - INFO - root - Finished sending 6874 states to Kinesis (batched)
# 2026-03-03 22:27:47,866 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:27:49,796 - INFO - root - Retrieved 6875 state vectors from OpenSky API
# 2026-03-03 22:27:49,843 - INFO - root - Sending 6875 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:27:49,884 - INFO - root - Finished sending 6875 states to Kinesis (batched)
# 2026-03-03 22:27:50,717 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:27:52,649 - INFO - root - Retrieved 6871 state vectors from OpenSky API
# 2026-03-03 22:27:52,704 - INFO - root - Sending 6871 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:27:52,763 - INFO - root - Finished sending 6871 states to Kinesis (batched)
# 2026-03-03 22:27:53,614 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:27:55,548 - INFO - root - Retrieved 6862 state vectors from OpenSky API
# 2026-03-03 22:27:55,595 - INFO - root - Sending 6862 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:27:55,642 - INFO - root - Finished sending 6862 states to Kinesis (batched)
# 2026-03-03 22:27:56,455 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:27:58,375 - INFO - root - Retrieved 6862 state vectors from OpenSky API
# 2026-03-03 22:27:58,418 - INFO - root - Sending 6862 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:27:58,461 - INFO - root - Finished sending 6862 states to Kinesis (batched)
# 2026-03-03 22:27:59,257 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:28:01,201 - INFO - root - Retrieved 6859 state vectors from OpenSky API
# 2026-03-03 22:28:01,248 - INFO - root - Sending 6859 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:28:01,290 - INFO - root - Finished sending 6859 states to Kinesis (batched)
# 2026-03-03 22:28:02,128 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:28:04,271 - INFO - root - Retrieved 6859 state vectors from OpenSky API
# 2026-03-03 22:28:04,330 - INFO - root - Sending 6859 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:28:04,386 - INFO - root - Finished sending 6859 states to Kinesis (batched)
# 2026-03-03 22:28:05,241 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:28:07,336 - INFO - root - Retrieved 6852 state vectors from OpenSky API
# 2026-03-03 22:28:07,388 - INFO - root - Sending 6852 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:28:07,452 - INFO - root - Finished sending 6852 states to Kinesis (batched)
# 2026-03-03 22:28:08,312 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:28:10,917 - INFO - root - Retrieved 6852 state vectors from OpenSky API
# 2026-03-03 22:28:10,962 - INFO - root - Sending 6852 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:28:11,011 - INFO - root - Finished sending 6852 states to Kinesis (batched)
# 2026-03-03 22:28:11,911 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:28:14,116 - INFO - root - Retrieved 6854 state vectors from OpenSky API
# 2026-03-03 22:28:14,166 - INFO - root - Sending 6854 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:28:14,217 - INFO - root - Finished sending 6854 states to Kinesis (batched)
# 2026-03-03 22:28:15,110 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:28:17,767 - INFO - root - Retrieved 6852 state vectors from OpenSky API
# 2026-03-03 22:28:17,821 - INFO - root - Sending 6852 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:28:17,870 - INFO - root - Finished sending 6852 states to Kinesis (batched)
# 2026-03-03 22:28:18,746 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:28:21,055 - INFO - root - Retrieved 6848 state vectors from OpenSky API
# 2026-03-03 22:28:21,103 - INFO - root - Sending 6848 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:28:21,145 - INFO - root - Finished sending 6848 states to Kinesis (batched)
# 2026-03-03 22:28:22,088 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:28:24,089 - INFO - root - Retrieved 6853 state vectors from OpenSky API
# 2026-03-03 22:28:24,138 - INFO - root - Sending 6853 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:28:24,180 - INFO - root - Finished sending 6853 states to Kinesis (batched)
# 2026-03-03 22:28:24,992 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:28:27,001 - INFO - root - Retrieved 6852 state vectors from OpenSky API
# 2026-03-03 22:28:27,049 - INFO - root - Sending 6852 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:28:27,102 - INFO - root - Finished sending 6852 states to Kinesis (batched)
# 2026-03-03 22:28:27,903 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:28:29,866 - INFO - root - Retrieved 6852 state vectors from OpenSky API
# 2026-03-03 22:28:29,910 - INFO - root - Sending 6852 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:28:29,960 - INFO - root - Finished sending 6852 states to Kinesis (batched)
# 2026-03-03 22:28:30,776 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:28:33,460 - INFO - root - Retrieved 6856 state vectors from OpenSky API
# 2026-03-03 22:28:33,515 - INFO - root - Sending 6856 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:28:33,566 - INFO - root - Finished sending 6856 states to Kinesis (batched)
# 2026-03-03 22:28:34,406 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:28:36,378 - INFO - root - Retrieved 6860 state vectors from OpenSky API
# 2026-03-03 22:28:36,419 - INFO - root - Sending 6860 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:28:36,464 - INFO - root - Finished sending 6860 states to Kinesis (batched)
# 2026-03-03 22:28:37,315 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:28:39,267 - INFO - root - Retrieved 6859 state vectors from OpenSky API
# 2026-03-03 22:28:39,312 - INFO - root - Sending 6859 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:28:39,353 - INFO - root - Finished sending 6859 states to Kinesis (batched)
# 2026-03-03 22:28:40,224 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:28:42,227 - INFO - root - Retrieved 6857 state vectors from OpenSky API
# 2026-03-03 22:28:42,270 - INFO - root - Sending 6857 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:28:42,313 - INFO - root - Finished sending 6857 states to Kinesis (batched)
# 2026-03-03 22:28:43,158 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:28:45,103 - INFO - root - Retrieved 6857 state vectors from OpenSky API
# 2026-03-03 22:28:45,158 - INFO - root - Sending 6857 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:28:45,208 - INFO - root - Finished sending 6857 states to Kinesis (batched)
# 2026-03-03 22:28:46,045 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:28:47,968 - INFO - root - Retrieved 6863 state vectors from OpenSky API
# 2026-03-03 22:28:48,013 - INFO - root - Sending 6863 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:28:48,053 - INFO - root - Finished sending 6863 states to Kinesis (batched)
# 2026-03-03 22:28:48,911 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:28:50,870 - INFO - root - Retrieved 6864 state vectors from OpenSky API
# 2026-03-03 22:28:50,914 - INFO - root - Sending 6864 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:28:50,956 - INFO - root - Finished sending 6864 states to Kinesis (batched)
# 2026-03-03 22:28:51,779 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:28:53,931 - INFO - root - Retrieved 6854 state vectors from OpenSky API
# 2026-03-03 22:28:53,976 - INFO - root - Sending 6854 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:28:54,020 - INFO - root - Finished sending 6854 states to Kinesis (batched)
# 2026-03-03 22:28:54,831 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:28:56,804 - INFO - root - Retrieved 6858 state vectors from OpenSky API
# 2026-03-03 22:28:56,847 - INFO - root - Sending 6858 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:28:56,888 - INFO - root - Finished sending 6858 states to Kinesis (batched)
# 2026-03-03 22:28:57,714 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:28:59,627 - INFO - root - Retrieved 6858 state vectors from OpenSky API
# 2026-03-03 22:28:59,677 - INFO - root - Sending 6858 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:28:59,726 - INFO - root - Finished sending 6858 states to Kinesis (batched)
# 2026-03-03 22:29:00,553 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:29:02,531 - INFO - root - Retrieved 6855 state vectors from OpenSky API
# 2026-03-03 22:29:02,572 - INFO - root - Sending 6855 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:29:02,619 - INFO - root - Finished sending 6855 states to Kinesis (batched)
# 2026-03-03 22:29:03,471 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:29:05,431 - INFO - root - Retrieved 6855 state vectors from OpenSky API
# 2026-03-03 22:29:05,481 - INFO - root - Sending 6855 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:29:05,532 - INFO - root - Finished sending 6855 states to Kinesis (batched)
# 2026-03-03 22:29:06,360 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:29:08,280 - INFO - root - Retrieved 6854 state vectors from OpenSky API
# 2026-03-03 22:29:08,326 - INFO - root - Sending 6854 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:29:08,367 - INFO - root - Finished sending 6854 states to Kinesis (batched)
# 2026-03-03 22:29:09,180 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:29:11,127 - INFO - root - Retrieved 6853 state vectors from OpenSky API
# 2026-03-03 22:29:11,170 - INFO - root - Sending 6853 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:29:11,213 - INFO - root - Finished sending 6853 states to Kinesis (batched)
# 2026-03-03 22:29:12,048 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:29:14,060 - INFO - root - Retrieved 6861 state vectors from OpenSky API
# 2026-03-03 22:29:14,104 - INFO - root - Sending 6861 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:29:14,149 - INFO - root - Finished sending 6861 states to Kinesis (batched)
# 2026-03-03 22:29:14,997 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:29:17,228 - INFO - root - Retrieved 6855 state vectors from OpenSky API
# 2026-03-03 22:29:17,273 - INFO - root - Sending 6855 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:29:17,316 - INFO - root - Finished sending 6855 states to Kinesis (batched)
# 2026-03-03 22:29:18,185 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:29:20,214 - INFO - root - Retrieved 6861 state vectors from OpenSky API
# 2026-03-03 22:29:20,257 - INFO - root - Sending 6861 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:29:20,314 - INFO - root - Finished sending 6861 states to Kinesis (batched)
# 2026-03-03 22:29:21,217 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:29:23,218 - INFO - root - Retrieved 6860 state vectors from OpenSky API
# 2026-03-03 22:29:23,267 - INFO - root - Sending 6860 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:29:23,314 - INFO - root - Finished sending 6860 states to Kinesis (batched)
# 2026-03-03 22:29:24,149 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:29:26,066 - INFO - root - Retrieved 6859 state vectors from OpenSky API
# 2026-03-03 22:29:26,119 - INFO - root - Sending 6859 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:29:26,161 - INFO - root - Finished sending 6859 states to Kinesis (batched)
# 2026-03-03 22:29:26,994 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:29:28,902 - INFO - root - Retrieved 6861 state vectors from OpenSky API
# 2026-03-03 22:29:28,945 - INFO - root - Sending 6861 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:29:28,992 - INFO - root - Finished sending 6861 states to Kinesis (batched)
# 2026-03-03 22:29:29,892 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:29:31,836 - INFO - root - Retrieved 6863 state vectors from OpenSky API
# 2026-03-03 22:29:31,885 - INFO - root - Sending 6863 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:29:31,930 - INFO - root - Finished sending 6863 states to Kinesis (batched)
# 2026-03-03 22:29:32,744 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:29:35,445 - INFO - root - Retrieved 6863 state vectors from OpenSky API
# 2026-03-03 22:29:35,553 - INFO - root - Sending 6863 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:29:35,602 - INFO - root - Finished sending 6863 states to Kinesis (batched)
# 2026-03-03 22:29:36,457 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:29:38,476 - INFO - root - Retrieved 6854 state vectors from OpenSky API
# 2026-03-03 22:29:38,531 - INFO - root - Sending 6854 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:29:38,583 - INFO - root - Finished sending 6854 states to Kinesis (batched)
# 2026-03-03 22:29:39,409 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:29:41,346 - INFO - root - Retrieved 6857 state vectors from OpenSky API
# 2026-03-03 22:29:41,403 - INFO - root - Sending 6857 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:29:41,452 - INFO - root - Finished sending 6857 states to Kinesis (batched)
# 2026-03-03 22:29:42,294 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:29:44,224 - INFO - root - Retrieved 6857 state vectors from OpenSky API
# 2026-03-03 22:29:44,266 - INFO - root - Sending 6857 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:29:44,307 - INFO - root - Finished sending 6857 states to Kinesis (batched)
# 2026-03-03 22:29:45,158 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:29:47,148 - INFO - root - Retrieved 6856 state vectors from OpenSky API
# 2026-03-03 22:29:47,194 - INFO - root - Sending 6856 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:29:47,239 - INFO - root - Finished sending 6856 states to Kinesis (batched)
# 2026-03-03 22:29:48,041 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:29:49,981 - INFO - root - Retrieved 6854 state vectors from OpenSky API
# 2026-03-03 22:29:50,036 - INFO - root - Sending 6854 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:29:50,079 - INFO - root - Finished sending 6854 states to Kinesis (batched)
# 2026-03-03 22:29:50,925 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:29:52,910 - INFO - root - Retrieved 6859 state vectors from OpenSky API
# 2026-03-03 22:29:52,957 - INFO - root - Sending 6859 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:29:52,998 - INFO - root - Finished sending 6859 states to Kinesis (batched)
# 2026-03-03 22:29:53,794 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:29:55,721 - INFO - root - Retrieved 6857 state vectors from OpenSky API
# 2026-03-03 22:29:55,765 - INFO - root - Sending 6857 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:29:55,810 - INFO - root - Finished sending 6857 states to Kinesis (batched)
# 2026-03-03 22:29:56,681 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:29:58,583 - INFO - root - Retrieved 6852 state vectors from OpenSky API
# 2026-03-03 22:29:58,637 - INFO - root - Sending 6852 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:29:58,692 - INFO - root - Finished sending 6852 states to Kinesis (batched)
# 2026-03-03 22:29:59,547 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:30:01,473 - INFO - root - Retrieved 6852 state vectors from OpenSky API
# 2026-03-03 22:30:01,522 - INFO - root - Sending 6852 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:30:01,575 - INFO - root - Finished sending 6852 states to Kinesis (batched)
# 2026-03-03 22:30:02,420 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:30:04,778 - INFO - root - Retrieved 6853 state vectors from OpenSky API
# 2026-03-03 22:30:04,824 - INFO - root - Sending 6853 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:30:04,875 - INFO - root - Finished sending 6853 states to Kinesis (batched)
# 2026-03-03 22:30:05,713 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:30:07,660 - INFO - root - Retrieved 6853 state vectors from OpenSky API
# 2026-03-03 22:30:07,712 - INFO - root - Sending 6853 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:30:07,751 - INFO - root - Finished sending 6853 states to Kinesis (batched)
# 2026-03-03 22:30:08,591 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:30:10,802 - INFO - root - Retrieved 6853 state vectors from OpenSky API
# 2026-03-03 22:30:10,848 - INFO - root - Sending 6853 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:30:10,891 - INFO - root - Finished sending 6853 states to Kinesis (batched)
# 2026-03-03 22:30:11,705 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:30:13,671 - INFO - root - Retrieved 6854 state vectors from OpenSky API
# 2026-03-03 22:30:13,753 - INFO - root - Sending 6854 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:30:13,869 - INFO - root - Finished sending 6854 states to Kinesis (batched)
# 2026-03-03 22:30:14,820 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:30:16,917 - INFO - root - Retrieved 6855 state vectors from OpenSky API
# 2026-03-03 22:30:16,960 - INFO - root - Sending 6855 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:30:17,002 - INFO - root - Finished sending 6855 states to Kinesis (batched)
# 2026-03-03 22:30:17,810 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:30:19,733 - INFO - root - Retrieved 6857 state vectors from OpenSky API
# 2026-03-03 22:30:19,786 - INFO - root - Sending 6857 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:30:19,853 - INFO - root - Finished sending 6857 states to Kinesis (batched)
# 2026-03-03 22:30:20,717 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:30:22,688 - INFO - root - Retrieved 6855 state vectors from OpenSky API
# 2026-03-03 22:30:22,737 - INFO - root - Sending 6855 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:30:22,781 - INFO - root - Finished sending 6855 states to Kinesis (batched)
# 2026-03-03 22:30:23,586 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:30:25,565 - INFO - root - Retrieved 6855 state vectors from OpenSky API
# 2026-03-03 22:30:25,611 - INFO - root - Sending 6855 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:30:25,663 - INFO - root - Finished sending 6855 states to Kinesis (batched)
# 2026-03-03 22:30:26,512 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:30:28,503 - INFO - root - Retrieved 6849 state vectors from OpenSky API
# 2026-03-03 22:30:28,553 - INFO - root - Sending 6849 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:30:28,610 - INFO - root - Finished sending 6849 states to Kinesis (batched)
# 2026-03-03 22:30:29,510 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:30:31,440 - INFO - root - Retrieved 6850 state vectors from OpenSky API
# 2026-03-03 22:30:31,492 - INFO - root - Sending 6850 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:30:31,546 - INFO - root - Finished sending 6850 states to Kinesis (batched)
# 2026-03-03 22:30:32,392 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:30:34,357 - INFO - root - Retrieved 6851 state vectors from OpenSky API
# 2026-03-03 22:30:34,401 - INFO - root - Sending 6851 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:30:34,442 - INFO - root - Finished sending 6851 states to Kinesis (batched)
# 2026-03-03 22:30:35,273 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:30:37,244 - INFO - root - Retrieved 6853 state vectors from OpenSky API
# 2026-03-03 22:30:37,324 - INFO - root - Sending 6853 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:30:37,378 - INFO - root - Finished sending 6853 states to Kinesis (batched)
# 2026-03-03 22:30:38,237 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:30:40,300 - INFO - root - Retrieved 6845 state vectors from OpenSky API
# 2026-03-03 22:30:40,346 - INFO - root - Sending 6845 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:30:40,390 - INFO - root - Finished sending 6845 states to Kinesis (batched)
# 2026-03-03 22:30:41,227 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:30:43,190 - INFO - root - Retrieved 6833 state vectors from OpenSky API
# 2026-03-03 22:30:43,245 - INFO - root - Sending 6833 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:30:43,293 - INFO - root - Finished sending 6833 states to Kinesis (batched)
# 2026-03-03 22:30:44,117 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:30:46,288 - INFO - root - Retrieved 6835 state vectors from OpenSky API
# 2026-03-03 22:30:46,339 - INFO - root - Sending 6835 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:30:46,393 - INFO - root - Finished sending 6835 states to Kinesis (batched)
# 2026-03-03 22:30:47,312 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:30:49,321 - INFO - root - Retrieved 6838 state vectors from OpenSky API
# 2026-03-03 22:30:49,381 - INFO - root - Sending 6838 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:30:49,441 - INFO - root - Finished sending 6838 states to Kinesis (batched)
# 2026-03-03 22:30:50,293 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:30:53,341 - INFO - root - Retrieved 6833 state vectors from OpenSky API
# 2026-03-03 22:30:53,391 - INFO - root - Sending 6833 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:30:53,448 - INFO - root - Finished sending 6833 states to Kinesis (batched)
# 2026-03-03 22:30:54,341 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:30:56,501 - INFO - root - Retrieved 6832 state vectors from OpenSky API
# 2026-03-03 22:30:56,543 - INFO - root - Sending 6832 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:30:56,589 - INFO - root - Finished sending 6832 states to Kinesis (batched)
# 2026-03-03 22:30:57,460 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:30:59,422 - INFO - root - Retrieved 6825 state vectors from OpenSky API
# 2026-03-03 22:30:59,497 - INFO - root - Sending 6825 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:30:59,566 - INFO - root - Finished sending 6825 states to Kinesis (batched)
# 2026-03-03 22:31:00,433 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:31:02,348 - INFO - root - Retrieved 6831 state vectors from OpenSky API
# 2026-03-03 22:31:02,393 - INFO - root - Sending 6831 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:31:02,438 - INFO - root - Finished sending 6831 states to Kinesis (batched)
# 2026-03-03 22:31:03,257 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:31:05,210 - INFO - root - Retrieved 6831 state vectors from OpenSky API
# 2026-03-03 22:31:05,256 - INFO - root - Sending 6831 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:31:05,301 - INFO - root - Finished sending 6831 states to Kinesis (batched)
# 2026-03-03 22:31:06,126 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:31:08,113 - INFO - root - Retrieved 6825 state vectors from OpenSky API
# 2026-03-03 22:31:08,160 - INFO - root - Sending 6825 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:31:08,209 - INFO - root - Finished sending 6825 states to Kinesis (batched)
# 2026-03-03 22:31:09,026 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:31:10,958 - INFO - root - Retrieved 6822 state vectors from OpenSky API
# 2026-03-03 22:31:11,007 - INFO - root - Sending 6822 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:31:11,059 - INFO - root - Finished sending 6822 states to Kinesis (batched)
# 2026-03-03 22:31:11,884 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:31:13,978 - INFO - root - Retrieved 6832 state vectors from OpenSky API
# 2026-03-03 22:31:14,027 - INFO - root - Sending 6832 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:31:14,072 - INFO - root - Finished sending 6832 states to Kinesis (batched)
# 2026-03-03 22:31:14,889 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:31:17,022 - INFO - root - Retrieved 6825 state vectors from OpenSky API
# 2026-03-03 22:31:17,067 - INFO - root - Sending 6825 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:31:17,109 - INFO - root - Finished sending 6825 states to Kinesis (batched)
# 2026-03-03 22:31:17,935 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:31:19,896 - INFO - root - Retrieved 6812 state vectors from OpenSky API
# 2026-03-03 22:31:19,942 - INFO - root - Sending 6812 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:31:19,982 - INFO - root - Finished sending 6812 states to Kinesis (batched)
# 2026-03-03 22:31:20,846 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:31:22,837 - INFO - root - Retrieved 6813 state vectors from OpenSky API
# 2026-03-03 22:31:22,880 - INFO - root - Sending 6813 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:31:22,927 - INFO - root - Finished sending 6813 states to Kinesis (batched)
# 2026-03-03 22:31:23,729 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:31:25,664 - INFO - root - Retrieved 6816 state vectors from OpenSky API
# 2026-03-03 22:31:25,717 - INFO - root - Sending 6816 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:31:25,764 - INFO - root - Finished sending 6816 states to Kinesis (batched)
# 2026-03-03 22:31:26,595 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:31:28,513 - INFO - root - Retrieved 6816 state vectors from OpenSky API
# 2026-03-03 22:31:28,559 - INFO - root - Sending 6816 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:31:28,607 - INFO - root - Finished sending 6816 states to Kinesis (batched)
# 2026-03-03 22:31:29,404 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:31:31,391 - INFO - root - Retrieved 6816 state vectors from OpenSky API
# 2026-03-03 22:31:31,437 - INFO - root - Sending 6816 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:31:31,481 - INFO - root - Finished sending 6816 states to Kinesis (batched)
# 2026-03-03 22:31:32,301 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:31:34,214 - INFO - root - Retrieved 6818 state vectors from OpenSky API
# 2026-03-03 22:31:34,311 - INFO - root - Sending 6818 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:31:34,354 - INFO - root - Finished sending 6818 states to Kinesis (batched)
# 2026-03-03 22:31:35,171 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:31:37,105 - INFO - root - Retrieved 6821 state vectors from OpenSky API
# 2026-03-03 22:31:37,153 - INFO - root - Sending 6821 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:31:37,199 - INFO - root - Finished sending 6821 states to Kinesis (batched)
# 2026-03-03 22:31:38,021 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:31:39,966 - INFO - root - Retrieved 6819 state vectors from OpenSky API
# 2026-03-03 22:31:40,017 - INFO - root - Sending 6819 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:31:40,066 - INFO - root - Finished sending 6819 states to Kinesis (batched)
# 2026-03-03 22:31:40,924 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:31:42,910 - INFO - root - Retrieved 6822 state vectors from OpenSky API
# 2026-03-03 22:31:42,954 - INFO - root - Sending 6822 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:31:42,997 - INFO - root - Finished sending 6822 states to Kinesis (batched)
# 2026-03-03 22:31:43,830 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:31:45,750 - INFO - root - Retrieved 6821 state vectors from OpenSky API
# 2026-03-03 22:31:45,793 - INFO - root - Sending 6821 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:31:45,836 - INFO - root - Finished sending 6821 states to Kinesis (batched)
# 2026-03-03 22:31:46,658 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:31:48,626 - INFO - root - Retrieved 6818 state vectors from OpenSky API
# 2026-03-03 22:31:48,678 - INFO - root - Sending 6818 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:31:48,723 - INFO - root - Finished sending 6818 states to Kinesis (batched)
# 2026-03-03 22:31:49,537 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:31:51,499 - INFO - root - Retrieved 6818 state vectors from OpenSky API
# 2026-03-03 22:31:51,544 - INFO - root - Sending 6818 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:31:51,589 - INFO - root - Finished sending 6818 states to Kinesis (batched)
# 2026-03-03 22:31:52,404 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:31:54,321 - INFO - root - Retrieved 6818 state vectors from OpenSky API
# 2026-03-03 22:31:54,376 - INFO - root - Sending 6818 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:31:54,425 - INFO - root - Finished sending 6818 states to Kinesis (batched)
# 2026-03-03 22:31:55,270 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:31:57,208 - INFO - root - Retrieved 6819 state vectors from OpenSky API
# 2026-03-03 22:31:57,252 - INFO - root - Sending 6819 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:31:57,298 - INFO - root - Finished sending 6819 states to Kinesis (batched)
# 2026-03-03 22:31:58,129 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:32:00,146 - INFO - root - Retrieved 6819 state vectors from OpenSky API
# 2026-03-03 22:32:00,201 - INFO - root - Sending 6819 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:32:00,263 - INFO - root - Finished sending 6819 states to Kinesis (batched)
# 2026-03-03 22:32:01,146 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:32:03,324 - INFO - root - Retrieved 6818 state vectors from OpenSky API
# 2026-03-03 22:32:03,382 - INFO - root - Sending 6818 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:32:03,435 - INFO - root - Finished sending 6818 states to Kinesis (batched)
# 2026-03-03 22:32:04,264 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:32:06,251 - INFO - root - Retrieved 6821 state vectors from OpenSky API
# 2026-03-03 22:32:06,302 - INFO - root - Sending 6821 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:32:06,357 - INFO - root - Finished sending 6821 states to Kinesis (batched)
# 2026-03-03 22:32:07,197 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:32:09,125 - INFO - root - Retrieved 6818 state vectors from OpenSky API
# 2026-03-03 22:32:09,171 - INFO - root - Sending 6818 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:32:09,214 - INFO - root - Finished sending 6818 states to Kinesis (batched)
# 2026-03-03 22:32:10,020 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:32:12,046 - INFO - root - Retrieved 6809 state vectors from OpenSky API
# 2026-03-03 22:32:12,099 - INFO - root - Sending 6809 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:32:12,187 - INFO - root - Finished sending 6809 states to Kinesis (batched)
# 2026-03-03 22:32:13,053 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:32:15,221 - INFO - root - Retrieved 6818 state vectors from OpenSky API
# 2026-03-03 22:32:15,275 - INFO - root - Sending 6818 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:32:15,331 - INFO - root - Finished sending 6818 states to Kinesis (batched)
# 2026-03-03 22:32:16,179 - INFO - root - Successfully obtained OpenSky access token
# 2026-03-03 22:32:18,090 - INFO - root - Retrieved 6813 state vectors from OpenSky API
# 2026-03-03 22:32:18,140 - INFO - root - Sending 6813 states to Kinesis stream 'flight-radar-stream-flights-raw' in batches of 500...
# 2026-03-03 22:32:18,188 - INFO - root - Finished sending 6813 states to Kinesis (batched)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 6
#       3 dt_start = datetime.now().isoformat()
#       5 while True:
# ----> 6     access_token = get_opensky_access_token()
#       7     states = get_opensky_states(access_token)
#       8     json_resultado = convert_states_response_to_json(states)
#
# Cell In[3], line 39, in get_opensky_access_token()
#      32 data = {
#      33     "grant_type": "client_credentials",
#      34     "client_id": client_id,
#      35     "client_secret": client_secret,
#      36 }
#      38 try:
# ---> 39     resp = requests.post(OPENSKY_TOKEN_URL, data=data, timeout=10)
#      40     resp.raise_for_status()
#      41     access_token = resp.json().get("access_token")
#
# File c:\repos\aws-streaming-flight-radar\.venv\Lib\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)    112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File c:\repos\aws-streaming-flight-radar\.venv\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\repos\aws-streaming-flight-radar\.venv\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\repos\aws-streaming-flight-radar\.venv\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\repos\aws-streaming-flight-radar\.venv\Lib\site-packages\requests\adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File c:\repos\aws-streaming-flight-radar\.venv\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File c:\repos\aws-streaming-flight-radar\.venv\Lib\site-packages\urllib3\connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     461 try:
#     462     # Trigger any extra validation we need to do.
#     463     try:
# --> 464         self._validate_conn(conn)
#     465     except (SocketTimeout, BaseSSLError) as e:
#     466         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File c:\repos\aws-streaming-flight-radar\.venv\Lib\site-packages\urllib3\connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1091 # Force connect early to allow us to validate the connection.
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#    1096 if not conn.is_verified and not conn.proxy_is_verified:
#
# File c:\repos\aws-streaming-flight-radar\.venv\Lib\site-packages\urllib3\connection.py:759, in HTTPSConnection.connect(self)
#     757 try:
#     758     sock: socket.socket | ssl.SSLSocket
# --> 759     self.sock = sock = self._new_conn()
#     760     server_hostname: str = self.host
#     761     tls_in_tls = False
#
# File c:\repos\aws-streaming-flight-radar\.venv\Lib\site-packages\urllib3\connection.py:204, in HTTPConnection._new_conn(self)
#     199 """Establish a socket connection and set nodelay settings on it.
#     200
#     201 :return: New socket connection.
#     202 """
#     203 try:
# --> 204     sock = connection.create_connection(
#     205         (self._dns_host, self.port),
#     206         self.timeout,
#     207         source_address=self.source_address,
#     208         socket_options=self.socket_options,
#     209     )
#     210 except socket.gaierror as e:
#     211     raise NameResolutionError(self.host, self, e) from e
#
# File c:\repos\aws-streaming-flight-radar\.venv\Lib\site-packages\urllib3\util\connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      57 except UnicodeError:
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ---> 60 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61     af, socktype, proto, canonname, sa = res
#      62     sock = None
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.3312.0_x64__qbz5n2kfra8p0\Lib\socket.py:977, in getaddrinfo(host, port, family, type, proto, flags)
#     974 # We override this function since we want to translate the numeric family
#     975 # and socket type values to enum constants.
#     976 addrlist = []
# --> 977 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     978     af, socktype, proto, canonname, sa = res
#     979     addrlist.append((_intenum_converter(af, AddressFamily),
#     980                      _intenum_converter(socktype, SocketKind),
#     981                      proto, canonname, sa))
#
# KeyboardInterrupt:
