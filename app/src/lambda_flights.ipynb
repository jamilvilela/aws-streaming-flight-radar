# %%
import os
import json
import logging

import boto3
import requests
from ingest_flights.utils.models import StateVector
from datetime import datetime

logger = logging.getLogger()
logger.setLevel(logging.INFO)

# AWS clients
secrets_client = boto3.client("secretsmanager")
kinesis_client = boto3.client("kinesis")

# OpenSky OAuth2 + API endpoints
OPENSKY_TOKEN_URL = (
    "https://auth.opensky-network.org/auth/realms/opensky-network/protocol/openid-connect/token"
)
OPENSKY_STATES_URL = "https://opensky-network.org/api/states/all"

# %%
def _get_opensky_credentials_from_secret():
    """
    Lê client_id e client_secret do AWS Secrets Manager.

    Espera que o secret (apontado por OPENSKY_SECRET_ARN) tenha o formato:
    {
      "client_id": "xxxx",
      "client_secret": "yyyy"
    }
    """
    try:
        client_id = os.environ.get("OPENSKY_client_id")
        client_secret = os.environ.get("OPENSKY_client_secret")
        if not client_id or not client_secret:
            logger.error("Credentials is missing in secret")
            return None, None
        return client_id, client_secret
    except Exception as e:
        logger.error(f"Error retrieving OpenSky credentials from Secrets Manager: {e}")
        return None, None

def get_opensky_access_token():
    """
    Autentica na OpenSky via OAuth2 Client Credentials e retorna o access_token (Bearer).
    """
    client_id, client_secret = _get_opensky_credentials_from_secret()
    if not client_id or not client_secret:
        return None

    data = {
        "grant_type": "client_credentials",
        "client_id": client_id,
        "client_secret": client_secret,
    }

    try:
        resp = requests.post(OPENSKY_TOKEN_URL, data=data, timeout=10)
        resp.raise_for_status()
        access_token = resp.json().get("access_token")
        if not access_token:
            logger.error("No access_token in OpenSky auth response")
            return None
        logger.info("Successfully obtained OpenSky access token")
        return access_token
    except requests.RequestException as e:
        logger.error(f"Error obtaining OpenSky access token: {e}")
        return None

def convert_states_response_to_json(states: list[StateVector]) -> dict:
    json_data = {
        "timestamp": datetime.now().isoformat(),
        "total_states": 0,
        "states": [],
    }
    for state in states:
        if state.origin_country != "Brazil":
            continue
        json_data["states"].append(state.to_dict())

    json_data["total_states"] = len(json_data["states"])
    return json_data

def send_state_to_kinesis(state_dict: dict) -> bool:
    """Envia um único registro para o Kinesis.

    Lê o nome do stream da variável de ambiente KINESIS_STREAM.
    Retorna True em caso de sucesso, False em caso de erro.
    """
    stream_name = os.environ.get("KINESIS_STREAM")
    if not stream_name:
        logger.error("KINESIS_STREAM environment variable not set")
        return False

    try:
        kinesis_client.put_record(
            StreamName=stream_name,
            Data=json.dumps(state_dict),
            PartitionKey=state_dict.get("icao24") or "unknown",
        )
        logger.info(
            f"State {state_dict.get('icao24', 'unknown')} sent to Kinesis successfully"
        )
        return True
    except Exception as e:
        logger.error(f"Error sending state to Kinesis: {e}")
        return False


def send_states_to_kinesis(json_resultado: dict) -> bool:
    """Envia todos os estados para o Kinesis.

    Retorna True se todos forem enviados com sucesso, False caso ocorra algum erro.
    """
    all_ok = True
    for state in json_resultado["states"]:
        ok = send_state_to_kinesis(state)
        if not ok:
            all_ok = False
    logger.info(
        f"Sent {len(json_resultado['states'])} states to Kinesis stream (check logs for failures)"
    )
    return all_ok


def get_opensky_states(access_token):
    """
    Chama o endpoint /api/states/all usando Bearer token e
    retorna uma lista de StateVector.
    """
    headers = {"Authorization": f"Bearer {access_token}"}

    try:
        resp = requests.get(OPENSKY_STATES_URL, headers=headers, timeout=15)
        resp.raise_for_status()
        body = resp.json()
    except requests.RequestException as e:
        logger.error(f"Error calling OpenSky states API: {e}")
        return []

    raw_states = body.get("states", []) or []
    states: list[StateVector] = []

    for row in raw_states:
        try:
            state = StateVector.from_api_response(row)
            states.append(state)
        except Exception as e:
            logger.warning(f"Failed to parse state vector: {e}")

    logger.info(f"Retrieved {len(states)} state vectors from OpenSky API")
    return states

# %%
access_token = get_opensky_access_token()
access_token
# Out:
# 'eyJhbGciOiJSUzI1NiIsInR5cCIgOiAiSldUIiwia2lkIiA6ICJ0SVIwSDB0bmNEZTlKYmp4dFctWEtqZ0RYSWExNnR5eU5DWHJxUzJQNkRjIn0.....ZXHjyhAv2s7nFWJg3KC2Ctwmo-HD2lC_00S04kgiYlO729w9nO7BRHGdOCrvUX-J0Wal2nTUWrr9wobulNlbkBuwSFWEntgE2cx9LkSVAq_Dvuap7pF_UMFPDCEhrpfVzBfzrQMbb1sXTpuu_p5E_AmfnIsBOZS5kBxopPMzIgph8mAzxMtXlf1FLD8qkwG6wvAVAcbeAMpf2VLVJzZAt878mRsITz6lENupNFJomv6ZGIQ-rL6Z5bEjm79-JEHpdfrSIgPENNh4M-aObqEX3bn5OtuUeRuIRVZAH7wfYxTF-Dadn6NPway1T1ilu8LGv4s9AMJRO6VCOritcvvTZQ'

# %%
states = get_opensky_states(access_token)

# %%
json_resultado = convert_states_response_to_json(states)

# %%
json_resultado
# Out:
# {'timestamp': '2026-02-07T13:12:22.608912',
#  'total_states': 127,
#  'states': [{'icao24': 'e4943e',
#    'callsign': 'GLO7481',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:13',
#    'last_contact': '2026-02-07T13:12:13',
#    'longitude': -54.9593,
#    'latitude': -25.547,
#    'altitude': 10668.0,
#    'on_ground': False,
#    'velocity': 238.99,
#    'heading': 94.69,
#    'vertical_rate': 0.98,
#    'sensors': None,
#    'geo_altitude': 11353.8,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e4943f',
#    'callsign': 'GLO9672',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -46.7251,
#    'latitude': -23.5274,
#    'altitude': 1348.74,
#    'on_ground': False,
#    'velocity': 89.99,
#    'heading': 149.04,
#    'vertical_rate': -1.95,
#    'sensors': None,
#    'geo_altitude': 1409.7,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e49443',
#    'callsign': 'AZU2450',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -35.8474,
#    'latitude': -9.1519,
#    'altitude': 8519.16,
#    'on_ground': False,
#    'velocity': 222.7,
#    'heading': 226.5,
#    'vertical_rate': 4.55,
#    'sensors': None,
#    'geo_altitude': 9044.94,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e49445',
#    'callsign': 'AZU2593',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -44.6625,
#    'latitude': -16.4041,
#    'altitude': 11590.02,
#    'on_ground': False,
#    'velocity': 235.66,
#    'heading': 222.08,
#    'vertical_rate': 0.0,
#    'sensors': None,
#    'geo_altitude': 12321.54,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e4944f',
#    'callsign': 'TAM3033',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:09:47',
#    'last_contact': '2026-02-07T13:09:47',
#    'longitude': -46.6585,
#    'latitude': -23.627,
#    'altitude': None,
#    'on_ground': True,
#    'velocity': 0.51,
#    'heading': 236.25,
#    'vertical_rate': None,
#    'sensors': None,
#    'geo_altitude': None,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e49422',
#    'callsign': 'PRLBE',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:07:21',
#    'last_contact': '2026-02-07T13:08:35',
#    'longitude': -35.0757,
#    'latitude': -7.869,
#    'altitude': 1188.72,
#    'on_ground': False,
#    'velocity': 73.65,
#    'heading': 87.2,
#    'vertical_rate': -2.28,
#    'sensors': None,
#    'geo_altitude': 1242.06,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e48be3',
#    'callsign': 'TAM3066',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:11:43',
#    'last_contact': '2026-02-07T13:11:51',
#    'longitude': -49.2489,
#    'latitude': -25.4631,
#    'altitude': 1348.74,
#    'on_ground': False,
#    'velocity': 86.94,
#    'heading': 134.76,
#    'vertical_rate': -4.23,
#    'sensors': None,
#    'geo_altitude': 1417.32,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e49eec',
#    'callsign': 'GLO1657',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:08:45',
#    'last_contact': '2026-02-07T13:09:11',
#    'longitude': -43.6195,
#    'latitude': -23.0999,
#    'altitude': 7132.32,
#    'on_ground': False,
#    'velocity': 202.88,
#    'heading': 245.9,
#    'vertical_rate': 9.43,
#    'sensors': None,
#    'geo_altitude': 7589.52,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e49eee',
#    'callsign': 'GLO1428',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -46.2876,
#    'latitude': -23.3236,
#    'altitude': 4572.0,
#    'on_ground': False,
#    'velocity': 157.3,
#    'heading': 12.08,
#    'vertical_rate': 0.98,
#    'sensors': None,
#    'geo_altitude': 4831.08,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e49eed',
#    'callsign': '',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:11:55',
#    'last_contact': '2026-02-07T13:11:55',
#    'longitude': -40.8581,
#    'latitude': -14.9654,
#    'altitude': 11582.4,
#    'on_ground': False,
#    'velocity': 238.12,
#    'heading': 222.55,
#    'vertical_rate': 0.0,
#    'sensors': None,
#    'geo_altitude': None,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e492a6',
#    'callsign': 'AZU2408',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -47.1514,
#    'latitude': -22.939,
#    'altitude': 1455.42,
#    'on_ground': False,
#    'velocity': 129.06,
#    'heading': 21.76,
#    'vertical_rate': 9.1,
#    'sensors': None,
#    'geo_altitude': 1493.52,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e49f9b',
#    'callsign': 'H160',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -46.5029,
#    'latitude': -23.6116,
#    'altitude': 982.98,
#    'on_ground': False,
#    'velocity': 73.07,
#    'heading': 99.73,
#    'vertical_rate': 0.0,
#    'sensors': None,
#    'geo_altitude': 1005.84,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e4803d',
#    'callsign': 'TAM8139',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:04:31',
#    'last_contact': '2026-02-07T13:08:21',
#    'longitude': -46.2667,
#    'latitude': -23.3791,
#    'altitude': 1714.5,
#    'on_ground': False,
#    'velocity': 72.78,
#    'heading': 254.0,
#    'vertical_rate': -3.25,
#    'sensors': None,
#    'geo_altitude': 1744.98,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e48045',
#    'callsign': 'TAM8142',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:11:56',
#    'last_contact': '2026-02-07T13:11:56',
#    'longitude': -56.0517,
#    'latitude': -32.7289,
#    'altitude': 10957.56,
#    'on_ground': False,
#    'velocity': 208.86,
#    'heading': 223.6,
#    'vertical_rate': -0.33,
#    'sensors': None,
#    'geo_altitude': 11414.76,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e48011',
#    'callsign': 'TAM3512',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:11:51',
#    'last_contact': '2026-02-07T13:11:52',
#    'longitude': -48.1523,
#    'latitude': -8.6867,
#    'altitude': 10957.56,
#    'on_ground': False,
#    'velocity': 243.15,
#    'heading': 11.6,
#    'vertical_rate': 0.0,
#    'sensors': None,
#    'geo_altitude': 11666.22,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e48c4d',
#    'callsign': 'TAM3152',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:10:48',
#    'last_contact': '2026-02-07T13:10:53',
#    'longitude': -48.3155,
#    'latitude': -25.9247,
#    'altitude': 10965.18,
#    'on_ground': False,
#    'velocity': 230.74,
#    'heading': 212.8,
#    'vertical_rate': 0.0,
#    'sensors': None,
#    'geo_altitude': 11628.12,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e48053',
#    'callsign': 'TAM3800',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:11:22',
#    'last_contact': '2026-02-07T13:11:22',
#    'longitude': -48.1259,
#    'latitude': -25.659,
#    'altitude': 10050.78,
#    'on_ground': False,
#    'velocity': 226.76,
#    'heading': 212.68,
#    'vertical_rate': 6.83,
#    'sensors': None,
#    'geo_altitude': 10629.9,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e4932a',
#    'callsign': 'AZU2641',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:13',
#    'last_contact': '2026-02-07T13:12:13',
#    'longitude': -40.4198,
#    'latitude': -17.9133,
#    'altitude': 11879.58,
#    'on_ground': False,
#    'velocity': 229.1,
#    'heading': 28.87,
#    'vertical_rate': 0.0,
#    'sensors': None,
#    'geo_altitude': 12603.48,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e49f52',
#    'callsign': 'AZU4680',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -47.525,
#    'latitude': -22.1735,
#    'altitude': 6987.54,
#    'on_ground': False,
#    'velocity': 182.38,
#    'heading': 321.64,
#    'vertical_rate': 6.83,
#    'sensors': None,
#    'geo_altitude': 7421.88,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e49f59',
#    'callsign': 'AZU2598',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:10',
#    'last_contact': '2026-02-07T13:12:11',
#    'longitude': -49.8795,
#    'latitude': -22.5824,
#    'altitude': 11887.2,
#    'on_ground': False,
#    'velocity': 238.53,
#    'heading': 47.71,
#    'vertical_rate': 0.0,
#    'sensors': None,
#    'geo_altitude': 12626.34,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e491b0',
#    'callsign': 'TAM3230',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -47.0862,
#    'latitude': -22.6114,
#    'altitude': 6324.6,
#    'on_ground': False,
#    'velocity': 202.79,
#    'heading': 352.71,
#    'vertical_rate': 9.75,
#    'sensors': None,
#    'geo_altitude': 6690.36,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e491c3',
#    'callsign': 'GLO2083',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:08',
#    'last_contact': '2026-02-07T13:12:08',
#    'longitude': -42.4854,
#    'latitude': -22.1072,
#    'altitude': 8161.02,
#    'on_ground': False,
#    'velocity': 217.14,
#    'heading': 245.8,
#    'vertical_rate': -11.7,
#    'sensors': None,
#    'geo_altitude': 8732.52,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e491f1',
#    'callsign': 'TAM3516',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -38.963,
#    'latitude': -4.0803,
#    'altitude': 2887.98,
#    'on_ground': False,
#    'velocity': 144.93,
#    'heading': 42.41,
#    'vertical_rate': -8.78,
#    'sensors': None,
#    'geo_altitude': 3070.86,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e49220',
#    'callsign': 'TAM8134',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:11:45',
#    'last_contact': '2026-02-07T13:11:45',
#    'longitude': -55.682,
#    'latitude': -32.3931,
#    'altitude': 10972.8,
#    'on_ground': False,
#    'velocity': 208.55,
#    'heading': 223.1,
#    'vertical_rate': 0.0,
#    'sensors': None,
#    'geo_altitude': 11430.0,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e49221',
#    'callsign': 'TAM3647',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -42.1977,
#    'latitude': -21.8285,
#    'altitude': 10401.3,
#    'on_ground': False,
#    'velocity': 227.1,
#    'heading': 209.29,
#    'vertical_rate': -11.38,
#    'sensors': None,
#    'geo_altitude': 11117.58,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e49295',
#    'callsign': 'AZU2407',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:13',
#    'last_contact': '2026-02-07T13:12:13',
#    'longitude': -47.2512,
#    'latitude': -23.2696,
#    'altitude': 2446.02,
#    'on_ground': False,
#    'velocity': 152.13,
#    'heading': 64.99,
#    'vertical_rate': -1.63,
#    'sensors': None,
#    'geo_altitude': 2567.94,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e49266',
#    'callsign': 'GLO9008',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -42.2193,
#    'latitude': -21.2872,
#    'altitude': 10180.32,
#    'on_ground': False,
#    'velocity': 243.13,
#    'heading': 36.48,
#    'vertical_rate': 8.13,
#    'sensors': None,
#    'geo_altitude': 10835.64,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e4a5a0',
#    'callsign': 'PSFXX',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:13',
#    'last_contact': '2026-02-07T13:12:13',
#    'longitude': -55.104,
#    'latitude': -22.75,
#    'altitude': 2834.64,
#    'on_ground': False,
#    'velocity': 62.61,
#    'heading': 47.0,
#    'vertical_rate': 1.63,
#    'sensors': None,
#    'geo_altitude': 3002.28,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e490f1',
#    'callsign': 'TAM3629',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -46.9115,
#    'latitude': -22.871,
#    'altitude': 6377.94,
#    'on_ground': False,
#    'velocity': 195.48,
#    'heading': 235.72,
#    'vertical_rate': -4.23,
#    'sensors': None,
#    'geo_altitude': 6797.04,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e4a4ad',
#    'callsign': 'PTFRV',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:09',
#    'last_contact': '2026-02-07T13:12:09',
#    'longitude': -48.475,
#    'latitude': -22.8731,
#    'altitude': 975.36,
#    'on_ground': False,
#    'velocity': 53.05,
#    'heading': 87.22,
#    'vertical_rate': 1.3,
#    'sensors': None,
#    'geo_altitude': 998.22,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e49baf',
#    'callsign': 'GLO2018',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -41.9541,
#    'latitude': -20.5331,
#    'altitude': 11871.96,
#    'on_ground': False,
#    'velocity': 233.1,
#    'heading': 29.34,
#    'vertical_rate': 2.93,
#    'sensors': None,
#    'geo_altitude': 12611.1,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e49bfe',
#    'callsign': 'TAM3676',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -45.0307,
#    'latitude': -22.7914,
#    'altitude': 8907.78,
#    'on_ground': False,
#    'velocity': 230.44,
#    'heading': 68.93,
#    'vertical_rate': 3.58,
#    'sensors': None,
#    'geo_altitude': 9502.14,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e4a54b',
#    'callsign': 'GLO1647',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -47.671,
#    'latitude': -23.6265,
#    'altitude': 7620.0,
#    'on_ground': False,
#    'velocity': 215.01,
#    'heading': 44.13,
#    'vertical_rate': 0.0,
#    'sensors': None,
#    'geo_altitude': 8092.44,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e4908e',
#    'callsign': 'AZU2331',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -42.5685,
#    'latitude': -16.783,
#    'altitude': 12192.0,
#    'on_ground': False,
#    'velocity': 237.25,
#    'heading': 218.49,
#    'vertical_rate': 0.0,
#    'sensors': None,
#    'geo_altitude': 12931.14,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e4a3b5',
#    'callsign': 'PSDZB',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:10:54',
#    'last_contact': '2026-02-07T13:11:57',
#    'longitude': -46.6336,
#    'latitude': -23.2826,
#    'altitude': 1196.34,
#    'on_ground': False,
#    'velocity': 48.0,
#    'heading': 107.46,
#    'vertical_rate': -1.3,
#    'sensors': None,
#    'geo_altitude': 1242.06,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e49c64',
#    'callsign': 'PRJHH',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:08:44',
#    'last_contact': '2026-02-07T13:08:44',
#    'longitude': -40.1227,
#    'latitude': -22.5646,
#    'altitude': 60.96,
#    'on_ground': False,
#    'velocity': 16.11,
#    'heading': 16.7,
#    'vertical_rate': -1.63,
#    'sensors': None,
#    'geo_altitude': 68.58,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e49c5a',
#    'callsign': 'TAM3361',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -46.969,
#    'latitude': -23.1569,
#    'altitude': 4907.28,
#    'on_ground': False,
#    'velocity': 187.35,
#    'heading': 97.57,
#    'vertical_rate': -8.45,
#    'sensors': None,
#    'geo_altitude': 5196.84,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e4987a',
#    'callsign': '',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:11:49',
#    'last_contact': '2026-02-07T13:11:51',
#    'longitude': -46.0154,
#    'latitude': -22.238,
#    'altitude': 5486.4,
#    'on_ground': False,
#    'velocity': 116.81,
#    'heading': 238.69,
#    'vertical_rate': 2.28,
#    'sensors': None,
#    'geo_altitude': 5806.44,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e49892',
#    'callsign': 'PRPUB',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -46.6349,
#    'latitude': -23.5475,
#    'altitude': 952.5,
#    'on_ground': False,
#    'velocity': 48.88,
#    'heading': 268.79,
#    'vertical_rate': 0.33,
#    'sensors': None,
#    'geo_altitude': 982.98,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e47e7e',
#    'callsign': 'GLO1215',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:11:46',
#    'last_contact': '2026-02-07T13:11:56',
#    'longitude': -47.2714,
#    'latitude': -23.7031,
#    'altitude': 4823.46,
#    'on_ground': False,
#    'velocity': 174.41,
#    'heading': 62.6,
#    'vertical_rate': -1.95,
#    'sensors': None,
#    'geo_altitude': 5113.02,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e4851b',
#    'callsign': '',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:06',
#    'last_contact': '2026-02-07T13:12:06',
#    'longitude': -38.5379,
#    'latitude': -3.7793,
#    'altitude': None,
#    'on_ground': True,
#    'velocity': 0.9,
#    'heading': 216.56,
#    'vertical_rate': None,
#    'sensors': None,
#    'geo_altitude': None,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e49830',
#    'callsign': 'AZU2768',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:11',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -34.9543,
#    'latitude': -8.2111,
#    'altitude': 899.16,
#    'on_ground': False,
#    'velocity': 151.16,
#    'heading': 257.62,
#    'vertical_rate': 11.7,
#    'sensors': None,
#    'geo_altitude': 952.5,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e48fcb',
#    'callsign': 'TAM3357',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:13',
#    'last_contact': '2026-02-07T13:12:13',
#    'longitude': -46.3585,
#    'latitude': -23.26,
#    'altitude': 2186.94,
#    'on_ground': False,
#    'velocity': 137.6,
#    'heading': 80.75,
#    'vertical_rate': -8.45,
#    'sensors': None,
#    'geo_altitude': 2316.48,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e495e8',
#    'callsign': '00000000',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -47.8446,
#    'latitude': -23.5483,
#    'altitude': 3893.82,
#    'on_ground': False,
#    'velocity': 165.94,
#    'heading': 86.62,
#    'vertical_rate': -19.51,
#    'sensors': None,
#    'geo_altitude': 4099.56,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e495cf',
#    'callsign': 'AZU4669',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -38.6489,
#    'latitude': -4.5591,
#    'altitude': 6880.86,
#    'on_ground': False,
#    'velocity': 192.46,
#    'heading': 198.87,
#    'vertical_rate': 12.03,
#    'sensors': None,
#    'geo_altitude': 7284.72,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e495b2',
#    'callsign': 'AZU2437',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -42.0813,
#    'latitude': -13.5083,
#    'altitude': 11582.4,
#    'on_ground': False,
#    'velocity': 233.36,
#    'heading': 221.07,
#    'vertical_rate': 0.0,
#    'sensors': None,
#    'geo_altitude': 12268.2,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e482c5',
#    'callsign': 'TAM3320',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:11',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -46.351,
#    'latitude': -23.6299,
#    'altitude': 2895.6,
#    'on_ground': False,
#    'velocity': 160.05,
#    'heading': 119.04,
#    'vertical_rate': 11.05,
#    'sensors': None,
#    'geo_altitude': 3032.76,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e48eff',
#    'callsign': 'GLO2037',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -41.7206,
#    'latitude': -21.0267,
#    'altitude': 11590.02,
#    'on_ground': False,
#    'velocity': 226.15,
#    'heading': 209.13,
#    'vertical_rate': 0.0,
#    'sensors': None,
#    'geo_altitude': 12329.16,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e495df',
#    'callsign': 'AZU2991',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -47.0379,
#    'latitude': -22.8674,
#    'altitude': 2186.94,
#    'on_ground': False,
#    'velocity': 153.28,
#    'heading': 64.98,
#    'vertical_rate': 5.85,
#    'sensors': None,
#    'geo_altitude': 2293.62,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e48396',
#    'callsign': 'GLO2129',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -39.9007,
#    'latitude': -19.1259,
#    'altitude': 7620.0,
#    'on_ground': False,
#    'velocity': 190.46,
#    'heading': 9.64,
#    'vertical_rate': 0.0,
#    'sensors': None,
#    'geo_altitude': 8107.68,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e49641',
#    'callsign': 'AZU2774',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -48.7516,
#    'latitude': -22.3111,
#    'altitude': 11887.2,
#    'on_ground': False,
#    'velocity': 237.0,
#    'heading': 121.69,
#    'vertical_rate': 0.0,
#    'sensors': None,
#    'geo_altitude': 12633.96,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e4962d',
#    'callsign': 'AZU2723',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -34.8358,
#    'latitude': -7.954,
#    'altitude': 5219.7,
#    'on_ground': False,
#    'velocity': 172.67,
#    'heading': 307.86,
#    'vertical_rate': 4.55,
#    'sensors': None,
#    'geo_altitude': 5516.88,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e4962e',
#    'callsign': 'AZU2823',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:08:58',
#    'last_contact': '2026-02-07T13:08:58',
#    'longitude': -36.2272,
#    'latitude': -9.7418,
#    'altitude': 10134.6,
#    'on_ground': False,
#    'velocity': 228.99,
#    'heading': 222.72,
#    'vertical_rate': 2.28,
#    'sensors': None,
#    'geo_altitude': 10660.38,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e48f22',
#    'callsign': 'PTZRQ',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -38.3465,
#    'latitude': -4.0255,
#    'altitude': 594.36,
#    'on_ground': False,
#    'velocity': 73.42,
#    'heading': 343.72,
#    'vertical_rate': -2.6,
#    'sensors': None,
#    'geo_altitude': 624.84,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e48f02',
#    'callsign': 'GLO1023',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:11',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -46.8284,
#    'latitude': -23.6463,
#    'altitude': 2697.48,
#    'on_ground': False,
#    'velocity': 110.99,
#    'heading': 300.96,
#    'vertical_rate': -7.48,
#    'sensors': None,
#    'geo_altitude': 2842.26,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e48f12',
#    'callsign': 'TAM3420',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:09:48',
#    'last_contact': '2026-02-07T13:09:48',
#    'longitude': -48.5226,
#    'latitude': -26.1582,
#    'altitude': 10363.2,
#    'on_ground': False,
#    'velocity': 227.67,
#    'heading': 212.07,
#    'vertical_rate': 0.0,
#    'sensors': None,
#    'geo_altitude': 10995.66,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e48f03',
#    'callsign': 'GLO1982',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:11:57',
#    'last_contact': '2026-02-07T13:12:01',
#    'longitude': -46.6124,
#    'latitude': -25.0902,
#    'altitude': 10972.8,
#    'on_ground': False,
#    'velocity': 230.27,
#    'heading': 233.54,
#    'vertical_rate': 0.0,
#    'sensors': None,
#    'geo_altitude': 11658.6,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e494b3',
#    'callsign': 'AZU2462',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -43.8336,
#    'latitude': -16.7233,
#    'altitude': 11582.4,
#    'on_ground': False,
#    'velocity': 237.99,
#    'heading': 233.53,
#    'vertical_rate': -0.33,
#    'sensors': None,
#    'geo_altitude': 12306.3,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e494b4',
#    'callsign': 'AZU4070',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:10:51',
#    'last_contact': '2026-02-07T13:10:51',
#    'longitude': -47.3308,
#    'latitude': -20.7995,
#    'altitude': 10363.2,
#    'on_ground': False,
#    'velocity': 242.06,
#    'heading': 4.63,
#    'vertical_rate': 0.0,
#    'sensors': None,
#    'geo_altitude': 11071.86,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e48dc1',
#    'callsign': '',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:08:07',
#    'last_contact': '2026-02-07T13:08:07',
#    'longitude': -49.4428,
#    'latitude': -25.5929,
#    'altitude': 3520.44,
#    'on_ground': False,
#    'velocity': 172.87,
#    'heading': 290.38,
#    'vertical_rate': 11.7,
#    'sensors': None,
#    'geo_altitude': 3718.56,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e48273',
#    'callsign': 'TAM3611',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:08:37',
#    'last_contact': '2026-02-07T13:10:30',
#    'longitude': -46.2782,
#    'latitude': -23.3793,
#    'altitude': 1356.36,
#    'on_ground': False,
#    'velocity': 75.19,
#    'heading': 253.3,
#    'vertical_rate': -5.53,
#    'sensors': None,
#    'geo_altitude': 1409.7,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e48274',
#    'callsign': 'TAM3492',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -38.6627,
#    'latitude': -3.7415,
#    'altitude': 731.52,
#    'on_ground': False,
#    'velocity': 78.61,
#    'heading': 104.4,
#    'vertical_rate': -4.23,
#    'sensors': None,
#    'geo_altitude': 792.48,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e4952b',
#    'callsign': '',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:09:46',
#    'last_contact': '2026-02-07T13:09:48',
#    'longitude': -43.0736,
#    'latitude': -18.8396,
#    'altitude': 11887.2,
#    'on_ground': False,
#    'velocity': 235.2,
#    'heading': 36.82,
#    'vertical_rate': 0.0,
#    'sensors': None,
#    'geo_altitude': 12641.58,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e48e55',
#    'callsign': 'TAM3490',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -38.532,
#    'latitude': -3.7781,
#    'altitude': None,
#    'on_ground': True,
#    'velocity': 9.77,
#    'heading': 284.06,
#    'vertical_rate': None,
#    'sensors': None,
#    'geo_altitude': None,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e48e0a',
#    'callsign': 'GLO2061',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -47.4255,
#    'latitude': -24.2395,
#    'altitude': 11887.2,
#    'on_ground': False,
#    'velocity': 237.69,
#    'heading': 89.38,
#    'vertical_rate': 0.0,
#    'sensors': None,
#    'geo_altitude': 12626.34,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e4950a',
#    'callsign': 'AZU2328',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:06',
#    'last_contact': '2026-02-07T13:12:13',
#    'longitude': -41.2325,
#    'latitude': -14.5643,
#    'altitude': 11582.4,
#    'on_ground': False,
#    'velocity': 233.7,
#    'heading': 221.16,
#    'vertical_rate': 0.0,
#    'sensors': None,
#    'geo_altitude': 12260.58,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e48e94',
#    'callsign': 'GLO1770',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:11:22',
#    'last_contact': '2026-02-07T13:11:22',
#    'longitude': -34.9348,
#    'latitude': -8.091,
#    'altitude': 167.64,
#    'on_ground': False,
#    'velocity': 78.42,
#    'heading': 162.04,
#    'vertical_rate': -4.88,
#    'sensors': None,
#    'geo_altitude': 198.12,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e4956e',
#    'callsign': 'GLO1429',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:13',
#    'last_contact': '2026-02-07T13:12:13',
#    'longitude': -48.2284,
#    'latitude': -20.7777,
#    'altitude': 11582.4,
#    'on_ground': False,
#    'velocity': 238.03,
#    'heading': 169.54,
#    'vertical_rate': 0.0,
#    'sensors': None,
#    'geo_altitude': 12336.78,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e4953a',
#    'callsign': 'AZU2574',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -43.9939,
#    'latitude': -15.2305,
#    'altitude': 11582.4,
#    'on_ground': False,
#    'velocity': 235.08,
#    'heading': 226.6,
#    'vertical_rate': 0.0,
#    'sensors': None,
#    'geo_altitude': 12298.68,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e48e77',
#    'callsign': 'GLO1277',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:11:35',
#    'last_contact': '2026-02-07T13:12:06',
#    'longitude': -46.2729,
#    'latitude': -23.2545,
#    'altitude': 1813.56,
#    'on_ground': False,
#    'velocity': 127.06,
#    'heading': 102.63,
#    'vertical_rate': 0.98,
#    'sensors': None,
#    'geo_altitude': 1897.38,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e480f9',
#    'callsign': 'TAM3266',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:10:30',
#    'last_contact': '2026-02-07T13:10:30',
#    'longitude': -47.9895,
#    'latitude': -20.1457,
#    'altitude': 10965.18,
#    'on_ground': False,
#    'velocity': 236.71,
#    'heading': 347.96,
#    'vertical_rate': 0.0,
#    'sensors': None,
#    'geo_altitude': 11704.32,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e480a4',
#    'callsign': 'TAM3231',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -47.9726,
#    'latitude': -7.171,
#    'altitude': 10050.78,
#    'on_ground': False,
#    'velocity': 238.37,
#    'heading': 177.77,
#    'vertical_rate': 0.0,
#    'sensors': None,
#    'geo_altitude': 10698.48,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e48ce6',
#    'callsign': 'TAM3627',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:08',
#    'last_contact': '2026-02-07T13:12:08',
#    'longitude': -45.2739,
#    'latitude': -22.1176,
#    'altitude': 10355.58,
#    'on_ground': False,
#    'velocity': 233.14,
#    'heading': 178.36,
#    'vertical_rate': 0.0,
#    'sensors': None,
#    'geo_altitude': 11056.62,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e48cbd',
#    'callsign': 'PRGMV',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:13',
#    'last_contact': '2026-02-07T13:12:13',
#    'longitude': -8.7325,
#    'latitude': 38.5472,
#    'altitude': 5844.54,
#    'on_ground': False,
#    'velocity': 112.4,
#    'heading': 218.5,
#    'vertical_rate': -5.2,
#    'sensors': None,
#    'geo_altitude': 5791.2,
#    'squawk': '4406',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e48198',
#    'callsign': 'TAM3839',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:06',
#    'last_contact': '2026-02-07T13:12:06',
#    'longitude': -48.7074,
#    'latitude': -25.4148,
#    'altitude': 11277.6,
#    'on_ground': False,
#    'velocity': 239.48,
#    'heading': 19.06,
#    'vertical_rate': 0.0,
#    'sensors': None,
#    'geo_altitude': 11978.64,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e4949f',
#    'callsign': 'AZU2478',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:08',
#    'last_contact': '2026-02-07T13:12:08',
#    'longitude': -41.794,
#    'latitude': -18.418,
#    'altitude': 10668.0,
#    'on_ground': False,
#    'velocity': 232.3,
#    'heading': 61.28,
#    'vertical_rate': 0.0,
#    'sensors': None,
#    'geo_altitude': 11369.04,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e48184',
#    'callsign': 'PTOKP',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:09',
#    'last_contact': '2026-02-07T13:12:09',
#    'longitude': -46.2616,
#    'latitude': -13.9066,
#    'altitude': 10355.58,
#    'on_ground': False,
#    'velocity': 175.43,
#    'heading': 226.9,
#    'vertical_rate': 0.0,
#    'sensors': None,
#    'geo_altitude': 11033.76,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e4894e',
#    'callsign': 'TAM3532',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:03',
#    'last_contact': '2026-02-07T13:12:09',
#    'longitude': -46.6577,
#    'latitude': -23.6269,
#    'altitude': None,
#    'on_ground': True,
#    'velocity': 2.06,
#    'heading': 2.81,
#    'vertical_rate': None,
#    'sensors': None,
#    'geo_altitude': None,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e4894f',
#    'callsign': 'TAM3822',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:11:53',
#    'last_contact': '2026-02-07T13:12:07',
#    'longitude': -49.3055,
#    'latitude': -25.4384,
#    'altitude': 10980.42,
#    'on_ground': False,
#    'velocity': 217.86,
#    'heading': 240.89,
#    'vertical_rate': 0.0,
#    'sensors': None,
#    'geo_altitude': 11643.36,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e48985',
#    'callsign': 'GLO9015',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -42.6031,
#    'latitude': -13.7682,
#    'altitude': 11277.6,
#    'on_ground': False,
#    'velocity': 222.22,
#    'heading': 71.65,
#    'vertical_rate': 0.0,
#    'sensors': None,
#    'geo_altitude': 11948.16,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e48986',
#    'callsign': 'GLO2094',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:11:31',
#    'last_contact': '2026-02-07T13:11:31',
#    'longitude': -41.0938,
#    'latitude': -15.3371,
#    'altitude': 11887.2,
#    'on_ground': False,
#    'velocity': 244.38,
#    'heading': 10.55,
#    'vertical_rate': 0.33,
#    'sensors': None,
#    'geo_altitude': 12580.62,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e48987',
#    'callsign': 'GLO9128',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -35.6039,
#    'latitude': -8.7894,
#    'altitude': 10500.36,
#    'on_ground': False,
#    'velocity': 226.33,
#    'heading': 218.35,
#    'vertical_rate': 6.18,
#    'sensors': None,
#    'geo_altitude': 11132.82,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e48855',
#    'callsign': '',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:00',
#    'last_contact': '2026-02-07T13:12:00',
#    'longitude': -46.6537,
#    'latitude': -23.6313,
#    'altitude': None,
#    'on_ground': True,
#    'velocity': 6.69,
#    'heading': 194.06,
#    'vertical_rate': None,
#    'sensors': None,
#    'geo_altitude': None,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e47fa6',
#    'callsign': 'TAM3600',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:07',
#    'last_contact': '2026-02-07T13:12:09',
#    'longitude': -43.0254,
#    'latitude': -21.3449,
#    'altitude': 11277.6,
#    'on_ground': False,
#    'velocity': 230.07,
#    'heading': 37.46,
#    'vertical_rate': 0.0,
#    'sensors': None,
#    'geo_altitude': 12016.74,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e486c2',
#    'callsign': 'TAM3585',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:01',
#    'last_contact': '2026-02-07T13:12:01',
#    'longitude': -46.6612,
#    'latitude': -23.6213,
#    'altitude': None,
#    'on_ground': True,
#    'velocity': 0.0,
#    'heading': 326.25,
#    'vertical_rate': None,
#    'sensors': None,
#    'geo_altitude': None,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e4875e',
#    'callsign': 'PRJDJ',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -54.4462,
#    'latitude': -22.7812,
#    'altitude': 11727.18,
#    'on_ground': False,
#    'velocity': 224.58,
#    'heading': 348.64,
#    'vertical_rate': 3.25,
#    'sensors': None,
#    'geo_altitude': 12527.28,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e47ed1',
#    'callsign': 'GLO2031',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:10',
#    'last_contact': '2026-02-07T13:12:10',
#    'longitude': -40.839,
#    'latitude': -17.8877,
#    'altitude': 11582.4,
#    'on_ground': False,
#    'velocity': 231.55,
#    'heading': 190.89,
#    'vertical_rate': 0.0,
#    'sensors': None,
#    'geo_altitude': 12291.06,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e4999e',
#    'callsign': 'TAM4786',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:08',
#    'last_contact': '2026-02-07T13:12:11',
#    'longitude': -38.5527,
#    'latitude': -3.7709,
#    'altitude': 83.82,
#    'on_ground': False,
#    'velocity': 68.13,
#    'heading': 104.88,
#    'vertical_rate': -3.58,
#    'sensors': None,
#    'geo_altitude': 83.82,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e4999f',
#    'callsign': 'TAM3265',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:08:58',
#    'last_contact': '2026-02-07T13:10:43',
#    'longitude': -47.3564,
#    'latitude': -20.8082,
#    'altitude': 10972.8,
#    'on_ground': False,
#    'velocity': 234.85,
#    'heading': 14.98,
#    'vertical_rate': 4.23,
#    'sensors': None,
#    'geo_altitude': 11734.8,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e4869d',
#    'callsign': 'PRETY',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:13',
#    'last_contact': '2026-02-07T13:12:13',
#    'longitude': -46.5913,
#    'latitude': -22.3561,
#    'altitude': 8625.84,
#    'on_ground': False,
#    'velocity': 223.35,
#    'heading': 225.19,
#    'vertical_rate': -9.1,
#    'sensors': None,
#    'geo_altitude': 9174.48,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e4995a',
#    'callsign': 'ACN5970',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:11:19',
#    'last_contact': '2026-02-07T13:11:20',
#    'longitude': -42.9718,
#    'latitude': -22.5236,
#    'altitude': 2743.2,
#    'on_ground': False,
#    'velocity': 86.99,
#    'heading': 12.64,
#    'vertical_rate': 0.0,
#    'sensors': None,
#    'geo_altitude': 2887.98,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e47f4f',
#    'callsign': 'GLO1684',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:11:25',
#    'last_contact': '2026-02-07T13:11:25',
#    'longitude': -41.5686,
#    'latitude': -20.7699,
#    'altitude': 10957.56,
#    'on_ground': False,
#    'velocity': 235.35,
#    'heading': 209.03,
#    'vertical_rate': 0.0,
#    'sensors': None,
#    'geo_altitude': 11673.84,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e48614',
#    'callsign': 'GLO1024',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -45.3886,
#    'latitude': -23.5532,
#    'altitude': 7010.4,
#    'on_ground': False,
#    'velocity': 213.12,
#    'heading': 103.4,
#    'vertical_rate': 0.33,
#    'sensors': None,
#    'geo_altitude': 7444.74,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e49957',
#    'callsign': 'GLO2055',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -41.5301,
#    'latitude': -20.7042,
#    'altitude': 11582.4,
#    'on_ground': False,
#    'velocity': 231.9,
#    'heading': 209.07,
#    'vertical_rate': 0.0,
#    'sensors': None,
#    'geo_altitude': 12329.16,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e49956',
#    'callsign': 'GLO1125',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:11',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -42.6339,
#    'latitude': -18.8184,
#    'altitude': 10972.8,
#    'on_ground': False,
#    'velocity': 245.98,
#    'heading': 251.34,
#    'vertical_rate': 0.0,
#    'sensors': None,
#    'geo_altitude': 11689.08,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e497be',
#    'callsign': 'PSBDJ',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -5.527,
#    'latitude': 41.2594,
#    'altitude': 12496.8,
#    'on_ground': False,
#    'velocity': 233.0,
#    'heading': 231.81,
#    'vertical_rate': 0.65,
#    'sensors': None,
#    'geo_altitude': 12397.74,
#    'squawk': '3741',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e497e6',
#    'callsign': 'GLO1545',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:11',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -46.3354,
#    'latitude': -23.3979,
#    'altitude': 1409.7,
#    'on_ground': False,
#    'velocity': 82.19,
#    'heading': 253.27,
#    'vertical_rate': -4.88,
#    'sensors': None,
#    'geo_altitude': 1478.28,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e49c0a',
#    'callsign': 'PTXXW',
#    'origin_country': 'Brazil',
#    'time_position': None,
#    'last_contact': '2026-02-07T13:11:49',
#    'longitude': None,
#    'latitude': None,
#    'altitude': None,
#    'on_ground': False,
#    'velocity': 33.97,
#    'heading': 88.26,
#    'vertical_rate': -0.33,
#    'sensors': None,
#    'geo_altitude': None,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e49c03',
#    'callsign': 'TAM3685',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -46.1397,
#    'latitude': -23.4806,
#    'altitude': 10660.38,
#    'on_ground': False,
#    'velocity': 247.31,
#    'heading': 81.15,
#    'vertical_rate': -0.33,
#    'sensors': None,
#    'geo_altitude': 11361.42,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e49c06',
#    'callsign': 'TAM3389',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:10',
#    'last_contact': '2026-02-07T13:12:11',
#    'longitude': -46.2244,
#    'latitude': -23.3552,
#    'altitude': 1760.22,
#    'on_ground': False,
#    'velocity': 93.41,
#    'heading': 243.15,
#    'vertical_rate': -0.33,
#    'sensors': None,
#    'geo_altitude': 1844.04,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e49c05',
#    'callsign': 'TAM3509',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -39.403,
#    'latitude': -3.5481,
#    'altitude': 4282.44,
#    'on_ground': False,
#    'velocity': 164.08,
#    'heading': 104.34,
#    'vertical_rate': -6.83,
#    'sensors': None,
#    'geo_altitude': 4518.66,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e49aa9',
#    'callsign': 'TAM3979',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -42.4189,
#    'latitude': -14.2193,
#    'altitude': 11597.64,
#    'on_ground': False,
#    'velocity': 244.95,
#    'heading': 241.39,
#    'vertical_rate': -0.33,
#    'sensors': None,
#    'geo_altitude': 12306.3,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e49aea',
#    'callsign': 'AZU4496',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -57.3791,
#    'latitude': -14.5969,
#    'altitude': 4869.18,
#    'on_ground': False,
#    'velocity': 132.27,
#    'heading': 311.69,
#    'vertical_rate': 0.0,
#    'sensors': None,
#    'geo_altitude': 5143.5,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e49af4',
#    'callsign': 'AZU2449',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -45.0458,
#    'latitude': -16.7267,
#    'altitude': 11894.82,
#    'on_ground': False,
#    'velocity': 230.02,
#    'heading': 43.19,
#    'vertical_rate': 0.0,
#    'sensors': None,
#    'geo_altitude': 12641.58,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e4a463',
#    'callsign': 'AP114',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:11:17',
#    'last_contact': '2026-02-07T13:11:17',
#    'longitude': -47.2311,
#    'latitude': -22.0911,
#    'altitude': 1592.58,
#    'on_ground': False,
#    'velocity': 45.69,
#    'heading': 262.23,
#    'vertical_rate': -0.65,
#    'sensors': None,
#    'geo_altitude': 1661.16,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e4a437',
#    'callsign': 'PSTPI',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -48.5145,
#    'latitude': -22.1959,
#    'altitude': 13106.4,
#    'on_ground': False,
#    'velocity': 238.83,
#    'heading': 115.79,
#    'vertical_rate': -5.2,
#    'sensors': None,
#    'geo_altitude': 13883.64,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e49b92',
#    'callsign': 'PSLUI',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -46.6055,
#    'latitude': -23.5131,
#    'altitude': 922.02,
#    'on_ground': False,
#    'velocity': 58.97,
#    'heading': 308.27,
#    'vertical_rate': -2.93,
#    'sensors': None,
#    'geo_altitude': 944.88,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e49b30',
#    'callsign': 'PPNLX',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:01',
#    'last_contact': '2026-02-07T13:12:01',
#    'longitude': -40.1983,
#    'latitude': -22.3884,
#    'altitude': 457.2,
#    'on_ground': False,
#    'velocity': 72.57,
#    'heading': 91.62,
#    'vertical_rate': -2.6,
#    'sensors': None,
#    'geo_altitude': 480.06,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e49b16',
#    'callsign': 'PSBTC',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -40.1079,
#    'latitude': -20.9141,
#    'altitude': 922.02,
#    'on_ground': False,
#    'velocity': 64.01,
#    'heading': 338.8,
#    'vertical_rate': 0.0,
#    'sensors': None,
#    'geo_altitude': 967.74,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e4a2d4',
#    'callsign': 'TAM3486',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -38.7552,
#    'latitude': -3.6978,
#    'altitude': 1447.8,
#    'on_ground': False,
#    'velocity': 103.31,
#    'heading': 17.98,
#    'vertical_rate': -5.85,
#    'sensors': None,
#    'geo_altitude': 1524.0,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e4a2c2',
#    'callsign': '00000000',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -42.37,
#    'latitude': -18.4047,
#    'altitude': 13716.0,
#    'on_ground': False,
#    'velocity': 220.07,
#    'heading': 39.31,
#    'vertical_rate': 0.33,
#    'sensors': None,
#    'geo_altitude': 14439.9,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e49b52',
#    'callsign': 'GLO1108',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -46.6685,
#    'latitude': -23.7649,
#    'altitude': 2004.06,
#    'on_ground': False,
#    'velocity': 137.01,
#    'heading': 234.94,
#    'vertical_rate': 3.9,
#    'sensors': None,
#    'geo_altitude': 2103.12,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e49b53',
#    'callsign': 'GLO1531',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:03',
#    'last_contact': '2026-02-07T13:12:03',
#    'longitude': -47.2969,
#    'latitude': -25.542,
#    'altitude': 11277.6,
#    'on_ground': False,
#    'velocity': 238.57,
#    'heading': 33.21,
#    'vertical_rate': 0.0,
#    'sensors': None,
#    'geo_altitude': 11971.02,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e49b57',
#    'callsign': 'PSBTD',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -40.1115,
#    'latitude': -20.894,
#    'altitude': 617.22,
#    'on_ground': False,
#    'velocity': 83.06,
#    'heading': 175.74,
#    'vertical_rate': 0.0,
#    'sensors': None,
#    'geo_altitude': 647.7,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e4a391',
#    'callsign': 'AZU4204',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -45.4515,
#    'latitude': -23.3637,
#    'altitude': 7620.0,
#    'on_ground': False,
#    'velocity': 189.5,
#    'heading': 102.23,
#    'vertical_rate': 0.0,
#    'sensors': None,
#    'geo_altitude': 8100.06,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e4a32a',
#    'callsign': 'PSBER',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:06',
#    'last_contact': '2026-02-07T13:12:06',
#    'longitude': -47.1758,
#    'latitude': -22.6344,
#    'altitude': 1363.98,
#    'on_ground': False,
#    'velocity': 39.38,
#    'heading': 236.73,
#    'vertical_rate': 2.6,
#    'sensors': None,
#    'geo_altitude': 1409.7,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e4a328',
#    'callsign': 'PSTAC',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:11',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -40.5084,
#    'latitude': -19.9509,
#    'altitude': 4427.22,
#    'on_ground': False,
#    'velocity': 117.18,
#    'heading': 159.97,
#    'vertical_rate': -8.13,
#    'sensors': None,
#    'geo_altitude': 4709.16,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e4a1e1',
#    'callsign': 'PTOCI',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:11',
#    'last_contact': '2026-02-07T13:12:11',
#    'longitude': -57.6153,
#    'latitude': -13.2027,
#    'altitude': 5486.4,
#    'on_ground': False,
#    'velocity': 113.11,
#    'heading': 328.77,
#    'vertical_rate': 0.0,
#    'sensors': None,
#    'geo_altitude': 5821.68,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e49a8a',
#    'callsign': 'AZU2253',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:08:20',
#    'last_contact': '2026-02-07T13:08:20',
#    'longitude': -43.3684,
#    'latitude': -16.8434,
#    'altitude': 11582.4,
#    'on_ground': False,
#    'velocity': 228.45,
#    'heading': 225.0,
#    'vertical_rate': 0.0,
#    'sensors': None,
#    'geo_altitude': 12291.06,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e49a6b',
#    'callsign': 'PRJHE',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:11:26',
#    'last_contact': '2026-02-07T13:11:29',
#    'longitude': -40.2606,
#    'latitude': -22.5605,
#    'altitude': 129.54,
#    'on_ground': False,
#    'velocity': 22.34,
#    'heading': 7.94,
#    'vertical_rate': -1.63,
#    'sensors': None,
#    'geo_altitude': 129.54,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e4a275',
#    'callsign': '',
#    'origin_country': 'Brazil',
#    'time_position': None,
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': None,
#    'latitude': None,
#    'altitude': None,
#    'on_ground': False,
#    'velocity': 52.03,
#    'heading': 136.2,
#    'vertical_rate': 0.33,
#    'sensors': None,
#    'geo_altitude': None,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e4a13d',
#    'callsign': 'AZU2040',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -48.3972,
#    'latitude': -7.4517,
#    'altitude': 10972.8,
#    'on_ground': False,
#    'velocity': 238.21,
#    'heading': 359.26,
#    'vertical_rate': 0.0,
#    'sensors': None,
#    'geo_altitude': 11673.84,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e4a12a',
#    'callsign': 'TAM3296',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -47.8257,
#    'latitude': -21.6353,
#    'altitude': 8747.76,
#    'on_ground': False,
#    'velocity': 219.46,
#    'heading': 330.97,
#    'vertical_rate': 3.58,
#    'sensors': None,
#    'geo_altitude': 9342.12,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e4a17d',
#    'callsign': 'PSNVT',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:07',
#    'last_contact': '2026-02-07T13:12:13',
#    'longitude': -38.5355,
#    'latitude': -3.7734,
#    'altitude': None,
#    'on_ground': True,
#    'velocity': 0.0,
#    'heading': 30.94,
#    'vertical_rate': None,
#    'sensors': None,
#    'geo_altitude': None,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e4a15a',
#    'callsign': 'PSBDZ',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:12',
#    'last_contact': '2026-02-07T13:12:12',
#    'longitude': -46.6714,
#    'latitude': -23.5603,
#    'altitude': 982.98,
#    'on_ground': False,
#    'velocity': 63.89,
#    'heading': 14.93,
#    'vertical_rate': 0.98,
#    'sensors': None,
#    'geo_altitude': 1013.46,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e4a161',
#    'callsign': 'PSVTS',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:09',
#    'last_contact': '2026-02-07T13:12:09',
#    'longitude': -46.0843,
#    'latitude': -23.5879,
#    'altitude': 1653.54,
#    'on_ground': False,
#    'velocity': 95.74,
#    'heading': 268.15,
#    'vertical_rate': 0.0,
#    'sensors': None,
#    'geo_altitude': 1722.12,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e4a06d',
#    'callsign': 'PSVTO',
#    'origin_country': 'Brazil',
#    'time_position': '2026-02-07T13:12:13',
#    'last_contact': '2026-02-07T13:12:13',
#    'longitude': -46.3197,
#    'latitude': -23.599,
#    'altitude': 1508.76,
#    'on_ground': False,
#    'velocity': 114.23,
#    'heading': 54.16,
#    'vertical_rate': 0.0,
#    'sensors': None,
#    'geo_altitude': 1569.72,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0}]}

# %%
ok = send_states_to_kinesis(json_resultado)
# Out:
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
# KINESIS_STREAM environment variable not set
